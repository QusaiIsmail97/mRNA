# %%
# !pip install rarfile
# !pip install catboost
# Out:
# Collecting rarfile
#   Downloading rarfile-4.0-py3-none-any.whl (28 kB)
# Installing collected packages: rarfile
# Successfully installed rarfile-4.0
# Collecting catboost
#   Downloading catboost-1.2-cp310-cp310-manylinux2014_x86_64.whl (98.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 MB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.23.5)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.10.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)
# Installing collected packages: catboost
# Successfully installed catboost-1.2

# %%
# Importing necessary libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.multioutput import MultiOutputRegressor
from sklearn.metrics import mean_squared_error
import rarfile
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from lightgbm import LGBMRegressor
from sklearn.preprocessing import StandardScaler
from catboost import CatBoostRegressor
import xgboost as xgb
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import AdaBoostRegressor

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Specify the path and filename of the RAR file
rar_path = '/content/drive/MyDrive/data/covid.rar'


# Specify the directory where you want to extract the files
extract_directory = '/content/data'
# Open the RAR file
with rarfile.RarFile(rar_path, 'r') as rar_ref:
    # Extract all the files to the specified directory
    rar_ref.extractall(extract_directory)

print('File extracted successfully.')
# Out:
# File extracted successfully.

# %%
# Load the dataset
train_data = pd.read_csv('/content/data/covid/train.csv')
train_data["id_seqpos"] = [id.split('_')[-1] for id in train_data["id_seqpos"]]

test_data = pd.read_csv('/content/data/covid/test.csv')
test_id = test_data['id_seqpos']
test_data["id_seqpos"] = [id.split('_')[-1] for id in test_data["id_seqpos"]]

# Drop target variables and id column
# Extract the multi-label target features
target_columns = ['reactivity', 'deg_Mg_pH10', 'deg_Mg_50C']
target_features = train_data[target_columns]
train_data = train_data.drop(['id'] + ["id_seqpos"], axis=1)

test_data=test_data.drop(['id']+["id_seqpos"], axis=1)

# %%
train_data
# Out:
#        sequence structure predicted_loop_type  reactivity  reactivity_error  \
# 0             A         .                   H      1.7786            0.1195
# 1             G         .                   I      0.4397            0.1033
# 2             G         (                   S      0.1120            0.1375
# 3             G         (                   S      0.0622            0.0471
# 4             U         (                   S      0.1378            0.1352
# ...         ...       ...                 ...         ...               ...
# 130555        U         )                   S      0.1244            0.0393
# 130556        A         .                   X      0.0201            0.0351
# 130557        A         .                   H      0.4597            0.0601
# 130558        G         .                   I      0.3634            0.1063
# 130559        C         .                   I      0.1458            0.0427
#
#         deg_Mg_pH10  deg_error_Mg_pH10  deg_pH10  deg_error_pH10  deg_Mg_50C  \
# 0            0.7346             0.0790    0.3680          0.0851      0.7228
# 1            0.1630             0.0799    0.0878          0.0878      0.1100
# 2            0.0000             0.0744    0.1835          0.1969      0.0933
# 3            0.1179             0.1075    0.0657          0.0615      0.0548
# 4            0.4069             0.2168    0.3375          0.2623      0.2378
# ...             ...                ...       ...             ...         ...
# 130555       0.2672             0.0728    0.1479          0.0493      0.1921
# 130556       0.1271             0.0583    0.0580          0.0660      0.0245
# 130557       0.2014             0.0515    0.2838          0.0793      0.2042
# 130558       0.1928             0.0738    0.1885          0.1276      0.1627
# 130559       0.4301             0.0687    0.2811          0.0800      0.3866
#
#         ...  b4_structure  a4_structure  b4_predicted_loop_type  \
# 0       ...             (             )                       S
# 1       ...             (             .                       S
# 2       ...             (             (                       S
# 3       ...             .             (                       E
# 4       ...             (             (                       S
# ...     ...           ...           ...                     ...
# 130555  ...             )             )                       S
# 130556  ...             .             .                       H
# 130557  ...             .             .                       H
# 130558  ...             )             .                       S
# 130559  ...             )             )                       S
#
#        a4_predicted_loop_type b5_sequence a5_sequence b5_structure  \
# 0                           S           C           A            .
# 1                           H           C           C            .
# 2                           S           A           G            (
# 3                           S           A           U            .
# 4                           S           G           G            (
# ...                       ...         ...         ...          ...
# 130555                      S           A           A            .
# 130556                      X           A           U            .
# 130557                      I           U           U            .
# 130558                      I           G           G            )
# 130559                      S           C           U            )
#
#        a5_structure b5_predicted_loop_type a5_predicted_loop_type
# 0                 )                      I                      S
# 1                 .                      B                      H
# 2                 (                      S                      S
# 3                 (                      E                      S
# 4                 .                      S                      H
# ...             ...                    ...                    ...
# 130555            .                      H                      M
# 130556            .                      H                      X
# 130557            )                      H                      S
# 130558            )                      S                      S
# 130559            )                      S                      S
#
# [130560 rows x 43 columns]

# %%
# Assuming df is your DataFrame

# Merge sequences
sequence_columns = ['sequence', 'b1_sequence', 'a1_sequence', 'b2_sequence', 'a2_sequence',
                    'b3_sequence', 'a3_sequence', 'b4_sequence', 'a4_sequence',
                    'b5_sequence', 'a5_sequence']
train_data['merged_sequence'] = train_data[sequence_columns].apply(lambda row: ''.join(row), axis=1)

# Merge structures
structure_columns = ['structure', 'b1_structure', 'a1_structure', 'b2_structure', 'a2_structure',
                     'b3_structure', 'a3_structure', 'b4_structure', 'a4_structure',
                     'b5_structure', 'a5_structure']
train_data['merged_structure'] = train_data[structure_columns].apply(lambda row: ''.join(row), axis=1)

# Merge predicted loop types
loop_type_columns = ['predicted_loop_type', 'b1_predicted_loop_type', 'a1_predicted_loop_type',
                     'b2_predicted_loop_type', 'a2_predicted_loop_type',
                     'b3_predicted_loop_type', 'a3_predicted_loop_type',
                     'b4_predicted_loop_type', 'a4_predicted_loop_type',
                     'b5_predicted_loop_type', 'a5_predicted_loop_type']
train_data['merged_predicted_loop_type'] = train_data[loop_type_columns].apply(lambda row: ''.join(row), axis=1)

# %%
train_data
# Out:
#        sequence structure predicted_loop_type  reactivity  reactivity_error  \
# 0             A         .                   H      1.7786            0.1195
# 1             G         .                   I      0.4397            0.1033
# 2             G         (                   S      0.1120            0.1375
# 3             G         (                   S      0.0622            0.0471
# 4             U         (                   S      0.1378            0.1352
# ...         ...       ...                 ...         ...               ...
# 130555        U         )                   S      0.1244            0.0393
# 130556        A         .                   X      0.0201            0.0351
# 130557        A         .                   H      0.4597            0.0601
# 130558        G         .                   I      0.3634            0.1063
# 130559        C         .                   I      0.1458            0.0427
#
#         deg_Mg_pH10  deg_error_Mg_pH10  deg_pH10  deg_error_pH10  deg_Mg_50C  \
# 0            0.7346             0.0790    0.3680          0.0851      0.7228
# 1            0.1630             0.0799    0.0878          0.0878      0.1100
# 2            0.0000             0.0744    0.1835          0.1969      0.0933
# 3            0.1179             0.1075    0.0657          0.0615      0.0548
# 4            0.4069             0.2168    0.3375          0.2623      0.2378
# ...             ...                ...       ...             ...         ...
# 130555       0.2672             0.0728    0.1479          0.0493      0.1921
# 130556       0.1271             0.0583    0.0580          0.0660      0.0245
# 130557       0.2014             0.0515    0.2838          0.0793      0.2042
# 130558       0.1928             0.0738    0.1885          0.1276      0.1627
# 130559       0.4301             0.0687    0.2811          0.0800      0.3866
#
#         ...  a4_predicted_loop_type  b5_sequence  a5_sequence b5_structure  \
# 0       ...                       S            C            A            .
# 1       ...                       H            C            C            .
# 2       ...                       S            A            G            (
# 3       ...                       S            A            U            .
# 4       ...                       S            G            G            (
# ...     ...                     ...          ...          ...          ...
# 130555  ...                       S            A            A            .
# 130556  ...                       X            A            U            .
# 130557  ...                       I            U            U            .
# 130558  ...                       I            G            G            )
# 130559  ...                       S            C            U            )
#
#        a5_structure b5_predicted_loop_type a5_predicted_loop_type  \
# 0                 )                      I                      S
# 1                 .                      B                      H
# 2                 (                      S                      S
# 3                 (                      E                      S
# 4                 .                      S                      H
# ...             ...                    ...                    ...
# 130555            .                      H                      M
# 130556            .                      H                      X
# 130557            )                      H                      S
# 130558            )                      S                      S
# 130559            )                      S                      S
#
#        merged_sequence merged_structure merged_predicted_loop_type
# 0          ACUGCUGGCCA      .(.(.()().)                HSHSHSSSSIS
# 1          GGACCAGGUCC      .(.(((((...                ISISSSSSHBH
# 2          GUGUGUAUUAG      (((((((((((                SSSSSSSSSSS
# 3          GCGGCGGAGAU      (((((((.(.(                SSSSSSSESES
# 4          UGACCAGUAGG      (.((((((((.                SBSSSSSSSSH
# ...                ...              ...                        ...
# 130555     UUGGAAGUAAA      )).).))))..                SSISISSSSHM
# 130556     AUACGGAAAAU      .).).).....                XSXSXSXHXHX
# 130557     AUCACAAUGUU      ..).).)...)                HHSHSHSHIHS
# 130558     GCGGUGGCGGG      .))))).).))                ISSSSSISISS
# 130559     CGUCACCGGCU      .))))))))))                ISSSSSSSSSS
#
# [130560 rows x 46 columns]

# %%
# Assuming df is your DataFrame

# Merge sequences
sequence_columns = ['sequence', 'b1_sequence', 'a1_sequence', 'b2_sequence', 'a2_sequence',
                    'b3_sequence', 'a3_sequence', 'b4_sequence', 'a4_sequence',
                    'b5_sequence', 'a5_sequence']
test_data['merged_sequence'] = test_data[sequence_columns].apply(lambda row: ''.join(row), axis=1)

# Merge structures
structure_columns = ['structure', 'b1_structure', 'a1_structure', 'b2_structure', 'a2_structure',
                     'b3_structure', 'a3_structure', 'b4_structure', 'a4_structure',
                     'b5_structure', 'a5_structure']
test_data['merged_structure'] = test_data[structure_columns].apply(lambda row: ''.join(row), axis=1)

# Merge predicted loop types
loop_type_columns = ['predicted_loop_type', 'b1_predicted_loop_type', 'a1_predicted_loop_type',
                     'b2_predicted_loop_type', 'a2_predicted_loop_type',
                     'b3_predicted_loop_type', 'a3_predicted_loop_type',
                     'b4_predicted_loop_type', 'a4_predicted_loop_type',
                     'b5_predicted_loop_type', 'a5_predicted_loop_type']
test_data['merged_predicted_loop_type'] = test_data[loop_type_columns].apply(lambda row: ''.join(row), axis=1)

# Drop the original sequence, structure, and predicted_loop_type columns if needed
#train_data.drop(sequence_columns + structure_columns + loop_type_columns, axis=1, inplace=True)

# Now your DataFrame has 'merged_sequence', 'merged_structure', and 'merged_predicted_loop_type' columns

# %%
def featurize(df):

    df['total_A_count'] = df['merged_sequence'].apply(lambda s: s.count('A'))
    df['total_G_count'] = df['merged_sequence'].apply(lambda s: s.count('G'))


    return df

# %%
train_data = featurize(train_data)
test_data = featurize(test_data)

# %%
train_data = train_data.drop(['merged_sequence', 'merged_structure', 'merged_predicted_loop_type'], axis=1)
test_data = test_data.drop(['merged_sequence', 'merged_structure', 'merged_predicted_loop_type'], axis=1)

# %%
train_data
# Out:
#        sequence structure predicted_loop_type  reactivity  reactivity_error  \
# 0             A         .                   H      1.7786            0.1195
# 1             G         .                   I      0.4397            0.1033
# 2             G         (                   S      0.1120            0.1375
# 3             G         (                   S      0.0622            0.0471
# 4             U         (                   S      0.1378            0.1352
# ...         ...       ...                 ...         ...               ...
# 130555        U         )                   S      0.1244            0.0393
# 130556        A         .                   X      0.0201            0.0351
# 130557        A         .                   H      0.4597            0.0601
# 130558        G         .                   I      0.3634            0.1063
# 130559        C         .                   I      0.1458            0.0427
#
#         deg_Mg_pH10  deg_error_Mg_pH10  deg_pH10  deg_error_pH10  deg_Mg_50C  \
# 0            0.7346             0.0790    0.3680          0.0851      0.7228
# 1            0.1630             0.0799    0.0878          0.0878      0.1100
# 2            0.0000             0.0744    0.1835          0.1969      0.0933
# 3            0.1179             0.1075    0.0657          0.0615      0.0548
# 4            0.4069             0.2168    0.3375          0.2623      0.2378
# ...             ...                ...       ...             ...         ...
# 130555       0.2672             0.0728    0.1479          0.0493      0.1921
# 130556       0.1271             0.0583    0.0580          0.0660      0.0245
# 130557       0.2014             0.0515    0.2838          0.0793      0.2042
# 130558       0.1928             0.0738    0.1885          0.1276      0.1627
# 130559       0.4301             0.0687    0.2811          0.0800      0.3866
#
#         ...  b4_predicted_loop_type  a4_predicted_loop_type  b5_sequence  \
# 0       ...                       S                       S            C
# 1       ...                       S                       H            C
# 2       ...                       S                       S            A
# 3       ...                       E                       S            A
# 4       ...                       S                       S            G
# ...     ...                     ...                     ...          ...
# 130555  ...                       S                       S            A
# 130556  ...                       H                       X            A
# 130557  ...                       H                       I            U
# 130558  ...                       S                       I            G
# 130559  ...                       S                       S            C
#
#        a5_sequence b5_structure a5_structure b5_predicted_loop_type  \
# 0                A            .            )                      I
# 1                C            .            .                      B
# 2                G            (            (                      S
# 3                U            .            (                      E
# 4                G            (            .                      S
# ...            ...          ...          ...                    ...
# 130555           A            .            .                      H
# 130556           U            .            .                      H
# 130557           U            .            )                      H
# 130558           G            )            )                      S
# 130559           U            )            )                      S
#
#        a5_predicted_loop_type total_A_count total_G_count
# 0                           S             2             3
# 1                           H             2             4
# 2                           S             2             4
# 3                           S             2             6
# 4                           H             3             4
# ...                       ...           ...           ...
# 130555                      M             5             3
# 130556                      X             6             2
# 130557                      S             4             1
# 130558                      S             0             8
# 130559                      S             1             3
#
# [130560 rows x 45 columns]

# %%
# Identify categorical columns
from sklearn.preprocessing import LabelEncoder
categorical_columns = train_data.select_dtypes(include=['object']).columns

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Apply LabelEncoder to all categorical columns in both training and test data
for column in categorical_columns:
    # Fit LabelEncoder using training data and apply to test data
    label_encoder.fit(train_data[column])
    train_data[column] = label_encoder.transform(train_data[column])

    # Transform test data with a 'transform' call, not 'fit_transform'
    test_data[column] = test_data[column].apply(lambda x: label_encoder.transform([x])[0] if x in label_encoder.classes_ else -1)  # Use -1 for unseen labels

# %%
'''import pandas as pd
from sklearn.preprocessing import OneHotEncoder

# Assume you have the 'train_data' and 'test_data' DataFrames

# Identify categorical columns
categorical_columns = train_data.select_dtypes(include=['object']).columns

# Initialize OneHotEncoder
onehot_encoder = OneHotEncoder(sparse=False, handle_unknown='ignore')

# Fit and transform OneHotEncoder on training data
encoded_train = onehot_encoder.fit_transform(train_data[categorical_columns])
encoded_train_df = pd.DataFrame(encoded_train, columns=onehot_encoder.get_feature_names_out(categorical_columns))

# Transform test data using the trained OneHotEncoder
encoded_test = onehot_encoder.transform(test_data[categorical_columns])
encoded_test_df = pd.DataFrame(encoded_test, columns=encoded_train_df.columns)

# Replace categorical columns with encoded columns in both training and test data
train_data_encoded = pd.concat([train_data.drop(categorical_columns, axis=1), encoded_train_df], axis=1)
test_data_encoded = pd.concat([test_data.drop(categorical_columns, axis=1), encoded_test_df], axis=1)'''
# Out:
# "import pandas as pd\nfrom sklearn.preprocessing import OneHotEncoder\n\n# Assume you have the 'train_data' and 'test_data' DataFrames\n\n# Identify categorical columns\ncategorical_columns = train_data.select_dtypes(include=['object']).columns\n\n# Initialize OneHotEncoder\nonehot_encoder = OneHotEncoder(sparse=False, handle_unknown='ignore')\n\n# Fit and transform OneHotEncoder on training data\nencoded_train = onehot_encoder.fit_transform(train_data[categorical_columns])\nencoded_train_df = pd.DataFrame(encoded_train, columns=onehot_encoder.get_feature_names_out(categorical_columns))\n\n# Transform test data using the trained OneHotEncoder\nencoded_test = onehot_encoder.transform(test_data[categorical_columns])\nencoded_test_df = pd.DataFrame(encoded_test, columns=encoded_train_df.columns)\n\n# Replace categorical columns with encoded columns in both training and test data\ntrain_data_encoded = pd.concat([train_data.drop(categorical_columns, axis=1), encoded_train_df], axis=1)\ntest_data_encoded = pd.concat([test_data.drop(categorical_columns, axis=1), encoded_test_df], axis=1)"

# %%
# Split data in features and labels
target = train_data[['reactivity', 'deg_Mg_pH10', 'deg_Mg_50C']]
train_data_encoded = train_data.drop(['reactivity', 'deg_Mg_pH10', 'deg_Mg_50C'], axis=1)

# %%
# Create a Random Forest model
model = RandomForestRegressor()  # For regression



# Fit the model on the training data
model.fit(train_data_encoded, target["reactivity"])

# Get feature importance scores
feature_importances = model.feature_importances_

# Create a DataFrame to store feature names and their importance scores
feature_importance_df = pd.DataFrame({'Feature': train_data_encoded.columns, 'Importance': feature_importances})

# Sort the DataFrame by importance scores in descending order
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# %%
# Normalize specified features using Min-Max scaling
scaler = MinMaxScaler()
features_to_normalize = ['reactivity_error', 'deg_pH10', 'deg_error_50C']
train_data_encoded[features_to_normalize] = scaler.fit_transform(train_data_encoded[features_to_normalize])

# Convert scaled values to a DataFrame for better display
train_data_encoded[features_to_normalize] = pd.DataFrame(train_data_encoded, columns=features_to_normalize)

# Display the scaled values with formatting
pd.set_option('display.float_format', '{:.10f}'.format)
train_data_encoded
# Out:
#         sequence  structure  predicted_loop_type  reactivity_error  \
# 0              0          2                    2      0.0000008046
# 1              2          2                    3      0.0000006938
# 2              2          0                    5      0.0000009278
# 3              2          0                    5      0.0000003093
# 4              3          0                    5      0.0000009121
# ...          ...        ...                  ...               ...
# 130555         3          1                    5      0.0000002559
# 130556         0          2                    6      0.0000002272
# 130557         0          2                    2      0.0000003982
# 130558         2          2                    3      0.0000007143
# 130559         1          2                    3      0.0000002792
#
#         deg_error_Mg_pH10     deg_pH10  deg_error_pH10  deg_error_Mg_50C  \
# 0            0.0790000000 0.5041000039    0.0851000000      0.0792000000
# 1            0.0799000000 0.5009529800    0.0878000000      0.0683000000
# 2            0.0744000000 0.5020278201    0.1969000000      0.1163000000
# 3            0.1075000000 0.5007047671    0.0615000000      0.0506000000
# 4            0.2168000000 0.5037574478    0.2623000000      0.1569000000
# ...                   ...          ...             ...               ...
# 130555       0.0728000000 0.5016279840    0.0493000000      0.0481000000
# 130556       0.0583000000 0.5006182858    0.0660000000      0.0419000000
# 130557       0.0515000000 0.5031543244    0.0793000000      0.0528000000
# 130558       0.0738000000 0.5020839768    0.1276000000      0.0773000000
# 130559       0.0687000000 0.5031239997    0.0800000000      0.0661000000
#
#             deg_50C  deg_error_50C  ...  b4_predicted_loop_type  \
# 0      0.5685000000   0.0000003636  ...                       6
# 1      0.0666000000   0.0000002947  ...                       6
# 2      0.0000000000   0.0000003773  ...                       6
# 3      0.0749000000   0.0000003127  ...                       2
# 4      0.6247000000   0.0000012188  ...                       6
# ...             ...            ...  ...                     ...
# 130555 0.4711000000   0.0000003017  ...                       6
# 130556 0.2559000000   0.0000003592  ...                       3
# 130557 0.3089000000   0.0000002936  ...                       3
# 130558 0.1001000000   0.0000004311  ...                       6
# 130559 0.2609000000   0.0000002843  ...                       6
#
#         a4_predicted_loop_type  b5_sequence  a5_sequence  b5_structure  \
# 0                            5            2            0             3
# 1                            2            2            1             3
# 2                            5            1            2             0
# 3                            5            1            3             3
# 4                            5            3            2             0
# ...                        ...          ...          ...           ...
# 130555                       5            1            0             3
# 130556                       6            1            3             3
# 130557                       3            4            3             3
# 130558                       3            3            2             1
# 130559                       5            2            3             1
#
#         a5_structure  b5_predicted_loop_type  a5_predicted_loop_type  \
# 0                  1                       4                       5
# 1                  2                       1                       2
# 2                  0                       6                       5
# 3                  0                       2                       5
# 4                  2                       6                       2
# ...              ...                     ...                     ...
# 130555             2                       3                       4
# 130556             2                       3                       6
# 130557             1                       3                       5
# 130558             1                       6                       5
# 130559             1                       6                       5
#
#         total_A_count  total_G_count
# 0                   2              3
# 1                   2              4
# 2                   2              4
# 3                   2              6
# 4                   3              4
# ...               ...            ...
# 130555              5              3
# 130556              6              2
# 130557              4              1
# 130558              0              8
# 130559              1              3
#
# [130560 rows x 42 columns]

# %%
# Assuming you have loaded your data into X_train, y_train, X_test, y_test, and defined target_features
X_train, X_test, y_train, y_test = train_test_split(train_data_encoded[feature_importance_df["Feature"]], target, test_size=0.20,random_state=42)

# %%
# Assuming you have loaded your data into X_train, y_train, X_test, y_test, and defined target_features

# Create a MultiOutputRegressor with CatBoost
catboost_model = MultiOutputRegressor(CatBoostRegressor(iterations=100, random_state=42))

# Train the model
catboost_model.fit(X_train, y_train)

# Predict target values on the test set
y_pred = catboost_model.predict(X_test)

# Calculate MCRMSE for each target
mcrmse_per_target = []
for i in range(len(target_features.columns)):
    mse = mean_squared_error(y_test.iloc[:, i], y_pred[:, i])
    mcrmse = np.sqrt(mse)
    mcrmse_per_target.append(mcrmse)

# Calculate average MCRMSE across all targets
average_mcrmse = np.mean(mcrmse_per_target)

# Print results
print("CatBoost Model")
for i, target in enumerate(target_features.columns):
    print(f"MCRMSE for {target}: {mcrmse_per_target[i]}")
print(f"Average MCRMSE: {average_mcrmse}\n")
# Out:
# Learning rate set to 0.5
# 0:	learn: 0.6499621	total: 35.6ms	remaining: 3.53s
# 1:	learn: 0.6070330	total: 83.9ms	remaining: 4.11s
# 2:	learn: 0.5866013	total: 109ms	remaining: 3.51s
# 3:	learn: 0.5751177	total: 143ms	remaining: 3.43s
# 4:	learn: 0.5661343	total: 177ms	remaining: 3.37s
# 5:	learn: 0.5552534	total: 202ms	remaining: 3.17s
# 6:	learn: 0.5480625	total: 231ms	remaining: 3.07s
# 7:	learn: 0.5425874	total: 260ms	remaining: 2.99s
# 8:	learn: 0.5353585	total: 283ms	remaining: 2.86s
# 9:	learn: 0.5299929	total: 308ms	remaining: 2.77s
# 10:	learn: 0.5256369	total: 345ms	remaining: 2.79s
# 11:	learn: 0.5199443	total: 371ms	remaining: 2.72s
# 12:	learn: 0.5145917	total: 401ms	remaining: 2.68s
# 13:	learn: 0.5123207	total: 427ms	remaining: 2.62s
# 14:	learn: 0.5093327	total: 453ms	remaining: 2.57s
# 15:	learn: 0.5070123	total: 485ms	remaining: 2.55s
# 16:	learn: 0.4994166	total: 512ms	remaining: 2.5s
# 17:	learn: 0.4971379	total: 561ms	remaining: 2.55s
# 18:	learn: 0.4934228	total: 585ms	remaining: 2.49s
# 19:	learn: 0.4905263	total: 614ms	remaining: 2.45s
# 20:	learn: 0.4845828	total: 645ms	remaining: 2.43s
# 21:	learn: 0.4830466	total: 669ms	remaining: 2.37s
# 22:	learn: 0.4817590	total: 707ms	remaining: 2.37s
# 23:	learn: 0.4785698	total: 731ms	remaining: 2.32s
# 24:	learn: 0.4755255	total: 770ms	remaining: 2.31s
# 25:	learn: 0.4728421	total: 793ms	remaining: 2.25s
# 26:	learn: 0.4693769	total: 816ms	remaining: 2.21s
# 27:	learn: 0.4681270	total: 848ms	remaining: 2.18s
# 28:	learn: 0.4668025	total: 877ms	remaining: 2.15s
# 29:	learn: 0.4633936	total: 903ms	remaining: 2.11s
# 30:	learn: 0.4605146	total: 941ms	remaining: 2.09s
# 31:	learn: 0.4567487	total: 982ms	remaining: 2.09s
# 32:	learn: 0.4543818	total: 1.01s	remaining: 2.06s
# 33:	learn: 0.4528691	total: 1.04s	remaining: 2.01s
# 34:	learn: 0.4506932	total: 1.08s	remaining: 2.01s
# 35:	learn: 0.4498542	total: 1.11s	remaining: 1.98s
# 36:	learn: 0.4473588	total: 1.14s	remaining: 1.94s
# 37:	learn: 0.4449598	total: 1.17s	remaining: 1.9s
# 38:	learn: 0.4440401	total: 1.2s	remaining: 1.88s
# 39:	learn: 0.4392272	total: 1.22s	remaining: 1.83s
# 40:	learn: 0.4375448	total: 1.24s	remaining: 1.79s
# 41:	learn: 0.4357931	total: 1.27s	remaining: 1.75s
# 42:	learn: 0.4347569	total: 1.3s	remaining: 1.72s
# 43:	learn: 0.4339964	total: 1.34s	remaining: 1.7s
# 44:	learn: 0.4333216	total: 1.36s	remaining: 1.66s
# 45:	learn: 0.4327651	total: 1.41s	remaining: 1.65s
# 46:	learn: 0.4308629	total: 1.43s	remaining: 1.61s
# 47:	learn: 0.4301279	total: 1.45s	remaining: 1.57s
# 48:	learn: 0.4288858	total: 1.48s	remaining: 1.54s
# 49:	learn: 0.4283588	total: 1.51s	remaining: 1.51s
# 50:	learn: 0.4276679	total: 1.54s	remaining: 1.48s
# 51:	learn: 0.4242758	total: 1.57s	remaining: 1.45s
# 52:	learn: 0.4216362	total: 1.6s	remaining: 1.42s
# 53:	learn: 0.4208795	total: 1.63s	remaining: 1.38s
# 54:	learn: 0.4186577	total: 1.65s	remaining: 1.35s
# 55:	learn: 0.4151820	total: 1.68s	remaining: 1.32s
# 56:	learn: 0.4125639	total: 1.72s	remaining: 1.29s
# 57:	learn: 0.4104657	total: 1.74s	remaining: 1.26s
# 58:	learn: 0.4089521	total: 1.77s	remaining: 1.23s
# 59:	learn: 0.4084813	total: 1.81s	remaining: 1.21s
# 60:	learn: 0.4071026	total: 1.85s	remaining: 1.18s
# 61:	learn: 0.4067246	total: 1.88s	remaining: 1.15s
# 62:	learn: 0.4052496	total: 1.9s	remaining: 1.12s
# 63:	learn: 0.4038767	total: 1.93s	remaining: 1.08s
# 64:	learn: 0.4018228	total: 1.96s	remaining: 1.05s
# 65:	learn: 0.4014213	total: 1.99s	remaining: 1.02s
# 66:	learn: 0.3973379	total: 2.02s	remaining: 995ms
# 67:	learn: 0.3957987	total: 2.05s	remaining: 964ms
# 68:	learn: 0.3920704	total: 2.09s	remaining: 941ms
# 69:	learn: 0.3916223	total: 2.13s	remaining: 912ms
# 70:	learn: 0.3907976	total: 2.17s	remaining: 884ms
# 71:	learn: 0.3903953	total: 2.19s	remaining: 853ms
# 72:	learn: 0.3863438	total: 2.22s	remaining: 821ms
# 73:	learn: 0.3846861	total: 2.25s	remaining: 790ms
# 74:	learn: 0.3844442	total: 2.28s	remaining: 760ms
# 75:	learn: 0.3836977	total: 2.31s	remaining: 729ms
# 76:	learn: 0.3809874	total: 2.33s	remaining: 697ms
# 77:	learn: 0.3790607	total: 2.36s	remaining: 666ms
# 78:	learn: 0.3786714	total: 2.39s	remaining: 635ms
# 79:	learn: 0.3777219	total: 2.42s	remaining: 604ms
# 80:	learn: 0.3766587	total: 2.44s	remaining: 573ms
# 81:	learn: 0.3758309	total: 2.46s	remaining: 541ms
# 82:	learn: 0.3747224	total: 2.5s	remaining: 512ms
# 83:	learn: 0.3724818	total: 2.53s	remaining: 482ms
# 84:	learn: 0.3722915	total: 2.56s	remaining: 451ms
# 85:	learn: 0.3718443	total: 2.58s	remaining: 421ms
# 86:	learn: 0.3713987	total: 2.61s	remaining: 391ms
# 87:	learn: 0.3709229	total: 2.63s	remaining: 359ms
# 88:	learn: 0.3689928	total: 2.66s	remaining: 329ms
# 89:	learn: 0.3683095	total: 2.69s	remaining: 298ms
# 90:	learn: 0.3670224	total: 2.72s	remaining: 269ms
# 91:	learn: 0.3658777	total: 2.75s	remaining: 239ms
# 92:	learn: 0.3650788	total: 2.78s	remaining: 209ms
# 93:	learn: 0.3646248	total: 2.8s	remaining: 179ms
# 94:	learn: 0.3640536	total: 2.84s	remaining: 149ms
# 95:	learn: 0.3632030	total: 2.87s	remaining: 119ms
# 96:	learn: 0.3621853	total: 2.9s	remaining: 89.5ms
# 97:	learn: 0.3617078	total: 2.92s	remaining: 59.6ms
# 98:	learn: 0.3609258	total: 2.94s	remaining: 29.7ms
# 99:	learn: 0.3606139	total: 2.98s	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.6060626	total: 29.2ms	remaining: 2.89s
# 1:	learn: 0.5640891	total: 54.9ms	remaining: 2.69s
# 2:	learn: 0.5421863	total: 105ms	remaining: 3.39s
# 3:	learn: 0.5290134	total: 130ms	remaining: 3.13s
# 4:	learn: 0.5194230	total: 158ms	remaining: 3s
# 5:	learn: 0.5112230	total: 190ms	remaining: 2.97s
# 6:	learn: 0.4943305	total: 212ms	remaining: 2.81s
# 7:	learn: 0.4888947	total: 241ms	remaining: 2.77s
# 8:	learn: 0.4834827	total: 267ms	remaining: 2.7s
# 9:	learn: 0.4788188	total: 298ms	remaining: 2.68s
# 10:	learn: 0.4734337	total: 333ms	remaining: 2.7s
# 11:	learn: 0.4696779	total: 356ms	remaining: 2.61s
# 12:	learn: 0.4662931	total: 386ms	remaining: 2.58s
# 13:	learn: 0.4636023	total: 419ms	remaining: 2.57s
# 14:	learn: 0.4603013	total: 443ms	remaining: 2.51s
# 15:	learn: 0.4538543	total: 467ms	remaining: 2.45s
# 16:	learn: 0.4507699	total: 501ms	remaining: 2.45s
# 17:	learn: 0.4487985	total: 534ms	remaining: 2.43s
# 18:	learn: 0.4460087	total: 560ms	remaining: 2.39s
# 19:	learn: 0.4439376	total: 591ms	remaining: 2.37s
# 20:	learn: 0.4409242	total: 614ms	remaining: 2.31s
# 21:	learn: 0.4383191	total: 642ms	remaining: 2.28s
# 22:	learn: 0.4364921	total: 669ms	remaining: 2.24s
# 23:	learn: 0.4354134	total: 704ms	remaining: 2.23s
# 24:	learn: 0.4331788	total: 728ms	remaining: 2.18s
# 25:	learn: 0.4313898	total: 750ms	remaining: 2.13s
# 26:	learn: 0.4305114	total: 781ms	remaining: 2.11s
# 27:	learn: 0.4291226	total: 813ms	remaining: 2.09s
# 28:	learn: 0.4271460	total: 837ms	remaining: 2.05s
# 29:	learn: 0.4234263	total: 885ms	remaining: 2.07s
# 30:	learn: 0.4218190	total: 910ms	remaining: 2.02s
# 31:	learn: 0.4207819	total: 945ms	remaining: 2.01s
# 32:	learn: 0.4196585	total: 976ms	remaining: 1.98s
# 33:	learn: 0.4184411	total: 998ms	remaining: 1.94s
# 34:	learn: 0.4165413	total: 1.03s	remaining: 1.91s
# 35:	learn: 0.4150342	total: 1.05s	remaining: 1.86s
# 36:	learn: 0.4134950	total: 1.07s	remaining: 1.83s
# 37:	learn: 0.4114921	total: 1.1s	remaining: 1.8s
# 38:	learn: 0.4101888	total: 1.13s	remaining: 1.76s
# 39:	learn: 0.4086411	total: 1.15s	remaining: 1.73s
# 40:	learn: 0.4080529	total: 1.18s	remaining: 1.7s
# 41:	learn: 0.4065477	total: 1.22s	remaining: 1.68s
# 42:	learn: 0.4055212	total: 1.24s	remaining: 1.65s
# 43:	learn: 0.4040772	total: 1.27s	remaining: 1.61s
# 44:	learn: 0.4017965	total: 1.29s	remaining: 1.58s
# 45:	learn: 0.4003055	total: 1.31s	remaining: 1.54s
# 46:	learn: 0.3981454	total: 1.34s	remaining: 1.51s
# 47:	learn: 0.3972853	total: 1.37s	remaining: 1.49s
# 48:	learn: 0.3964719	total: 1.4s	remaining: 1.45s
# 49:	learn: 0.3946794	total: 1.42s	remaining: 1.42s
# 50:	learn: 0.3939318	total: 1.45s	remaining: 1.4s
# 51:	learn: 0.3927009	total: 1.49s	remaining: 1.37s
# 52:	learn: 0.3920391	total: 1.52s	remaining: 1.35s
# 53:	learn: 0.3911888	total: 1.55s	remaining: 1.32s
# 54:	learn: 0.3900185	total: 1.57s	remaining: 1.29s
# 55:	learn: 0.3892491	total: 1.6s	remaining: 1.26s
# 56:	learn: 0.3879772	total: 1.63s	remaining: 1.23s
# 57:	learn: 0.3869501	total: 1.66s	remaining: 1.2s
# 58:	learn: 0.3865319	total: 1.69s	remaining: 1.17s
# 59:	learn: 0.3852983	total: 1.72s	remaining: 1.14s
# 60:	learn: 0.3841075	total: 1.75s	remaining: 1.12s
# 61:	learn: 0.3836334	total: 1.78s	remaining: 1.09s
# 62:	learn: 0.3831127	total: 1.81s	remaining: 1.06s
# 63:	learn: 0.3819697	total: 1.84s	remaining: 1.03s
# 64:	learn: 0.3808134	total: 1.88s	remaining: 1.01s
# 65:	learn: 0.3802790	total: 1.91s	remaining: 985ms
# 66:	learn: 0.3798825	total: 1.94s	remaining: 954ms
# 67:	learn: 0.3793231	total: 1.97s	remaining: 927ms
# 68:	learn: 0.3787270	total: 2s	remaining: 897ms
# 69:	learn: 0.3779711	total: 2.02s	remaining: 866ms
# 70:	learn: 0.3774341	total: 2.05s	remaining: 836ms
# 71:	learn: 0.3764650	total: 2.07s	remaining: 806ms
# 72:	learn: 0.3761305	total: 2.11s	remaining: 781ms
# 73:	learn: 0.3751948	total: 2.14s	remaining: 752ms
# 74:	learn: 0.3743203	total: 2.16s	remaining: 721ms
# 75:	learn: 0.3738382	total: 2.19s	remaining: 692ms
# 76:	learn: 0.3730868	total: 2.22s	remaining: 663ms
# 77:	learn: 0.3724406	total: 2.25s	remaining: 633ms
# 78:	learn: 0.3710403	total: 2.27s	remaining: 603ms
# 79:	learn: 0.3703725	total: 2.29s	remaining: 574ms
# 80:	learn: 0.3699573	total: 2.33s	remaining: 547ms
# 81:	learn: 0.3695697	total: 2.35s	remaining: 517ms
# 82:	learn: 0.3691862	total: 2.38s	remaining: 488ms
# 83:	learn: 0.3685233	total: 2.41s	remaining: 460ms
# 84:	learn: 0.3681493	total: 2.45s	remaining: 432ms
# 85:	learn: 0.3675695	total: 2.48s	remaining: 404ms
# 86:	learn: 0.3666926	total: 2.5s	remaining: 374ms
# 87:	learn: 0.3660273	total: 2.53s	remaining: 345ms
# 88:	learn: 0.3651167	total: 2.56s	remaining: 316ms
# 89:	learn: 0.3643445	total: 2.59s	remaining: 287ms
# 90:	learn: 0.3635613	total: 2.62s	remaining: 259ms
# 91:	learn: 0.3633485	total: 2.65s	remaining: 230ms
# 92:	learn: 0.3630589	total: 2.67s	remaining: 201ms
# 93:	learn: 0.3628023	total: 2.71s	remaining: 173ms
# 94:	learn: 0.3621054	total: 2.73s	remaining: 144ms
# 95:	learn: 0.3615275	total: 2.77s	remaining: 115ms
# 96:	learn: 0.3607063	total: 2.79s	remaining: 86.4ms
# 97:	learn: 0.3594065	total: 2.84s	remaining: 57.9ms
# 98:	learn: 0.3586473	total: 2.86s	remaining: 28.9ms
# 99:	learn: 0.3583680	total: 2.91s	remaining: 0us
# Learning rate set to 0.5
# 0:	learn: 0.7189209	total: 34.5ms	remaining: 3.41s
# 1:	learn: 0.6629707	total: 61.3ms	remaining: 3s
# 2:	learn: 0.6320985	total: 87.6ms	remaining: 2.83s
# 3:	learn: 0.6206109	total: 117ms	remaining: 2.8s
# 4:	learn: 0.6068888	total: 144ms	remaining: 2.74s
# 5:	learn: 0.6011500	total: 177ms	remaining: 2.77s
# 6:	learn: 0.5940174	total: 203ms	remaining: 2.7s
# 7:	learn: 0.5874378	total: 229ms	remaining: 2.63s
# 8:	learn: 0.5829311	total: 254ms	remaining: 2.57s
# 9:	learn: 0.5762653	total: 283ms	remaining: 2.54s
# 10:	learn: 0.5730106	total: 312ms	remaining: 2.52s
# 11:	learn: 0.5690590	total: 343ms	remaining: 2.51s
# 12:	learn: 0.5659915	total: 376ms	remaining: 2.51s
# 13:	learn: 0.5636281	total: 422ms	remaining: 2.6s
# 14:	learn: 0.5535561	total: 446ms	remaining: 2.52s
# 15:	learn: 0.5517534	total: 480ms	remaining: 2.52s
# 16:	learn: 0.5475065	total: 513ms	remaining: 2.51s
# 17:	learn: 0.5420376	total: 540ms	remaining: 2.46s
# 18:	learn: 0.5373910	total: 562ms	remaining: 2.4s
# 19:	learn: 0.5357772	total: 593ms	remaining: 2.37s
# 20:	learn: 0.5348636	total: 626ms	remaining: 2.35s
# 21:	learn: 0.5319840	total: 649ms	remaining: 2.3s
# 22:	learn: 0.5284662	total: 670ms	remaining: 2.24s
# 23:	learn: 0.5254089	total: 696ms	remaining: 2.2s
# 24:	learn: 0.5240902	total: 732ms	remaining: 2.19s
# 25:	learn: 0.5210746	total: 771ms	remaining: 2.19s
# 26:	learn: 0.5167395	total: 792ms	remaining: 2.14s
# 27:	learn: 0.5118296	total: 816ms	remaining: 2.1s
# 28:	learn: 0.5080427	total: 858ms	remaining: 2.1s
# 29:	learn: 0.5062423	total: 882ms	remaining: 2.06s
# 30:	learn: 0.5048389	total: 909ms	remaining: 2.02s
# 31:	learn: 0.5034715	total: 938ms	remaining: 1.99s
# 32:	learn: 0.5021901	total: 968ms	remaining: 1.96s
# 33:	learn: 0.4996695	total: 990ms	remaining: 1.92s
# 34:	learn: 0.4969922	total: 1.01s	remaining: 1.88s
# 35:	learn: 0.4947329	total: 1.04s	remaining: 1.85s
# 36:	learn: 0.4935456	total: 1.07s	remaining: 1.82s
# 37:	learn: 0.4921011	total: 1.1s	remaining: 1.79s
# 38:	learn: 0.4892412	total: 1.12s	remaining: 1.76s
# 39:	learn: 0.4876999	total: 1.15s	remaining: 1.72s
# 40:	learn: 0.4856250	total: 1.18s	remaining: 1.71s
# 41:	learn: 0.4847504	total: 1.22s	remaining: 1.68s
# 42:	learn: 0.4835297	total: 1.25s	remaining: 1.65s
# 43:	learn: 0.4812066	total: 1.28s	remaining: 1.63s
# 44:	learn: 0.4760324	total: 1.33s	remaining: 1.63s
# 45:	learn: 0.4735184	total: 1.38s	remaining: 1.62s
# 46:	learn: 0.4669106	total: 1.42s	remaining: 1.6s
# 47:	learn: 0.4654534	total: 1.46s	remaining: 1.58s
# 48:	learn: 0.4611389	total: 1.5s	remaining: 1.56s
# 49:	learn: 0.4599604	total: 1.53s	remaining: 1.53s
# 50:	learn: 0.4576116	total: 1.58s	remaining: 1.51s
# 51:	learn: 0.4558362	total: 1.64s	remaining: 1.52s
# 52:	learn: 0.4551038	total: 1.73s	remaining: 1.53s
# 53:	learn: 0.4530310	total: 1.78s	remaining: 1.52s
# 54:	learn: 0.4524597	total: 1.83s	remaining: 1.5s
# 55:	learn: 0.4515636	total: 1.89s	remaining: 1.49s
# 56:	learn: 0.4498715	total: 1.95s	remaining: 1.47s
# 57:	learn: 0.4477981	total: 1.99s	remaining: 1.44s
# 58:	learn: 0.4439128	total: 2.03s	remaining: 1.41s
# 59:	learn: 0.4430321	total: 2.08s	remaining: 1.39s
# 60:	learn: 0.4415295	total: 2.13s	remaining: 1.36s
# 61:	learn: 0.4411380	total: 2.21s	remaining: 1.35s
# 62:	learn: 0.4398450	total: 2.26s	remaining: 1.33s
# 63:	learn: 0.4393958	total: 2.32s	remaining: 1.3s
# 64:	learn: 0.4386210	total: 2.37s	remaining: 1.28s
# 65:	learn: 0.4382989	total: 2.45s	remaining: 1.26s
# 66:	learn: 0.4373583	total: 2.5s	remaining: 1.23s
# 67:	learn: 0.4366667	total: 2.56s	remaining: 1.21s
# 68:	learn: 0.4360379	total: 2.63s	remaining: 1.18s
# 69:	learn: 0.4336805	total: 2.69s	remaining: 1.16s
# 70:	learn: 0.4308393	total: 2.76s	remaining: 1.13s
# 71:	learn: 0.4295981	total: 2.82s	remaining: 1.1s
# 72:	learn: 0.4285784	total: 2.87s	remaining: 1.06s
# 73:	learn: 0.4281274	total: 2.95s	remaining: 1.04s
# 74:	learn: 0.4266704	total: 3.01s	remaining: 1s
# 75:	learn: 0.4257377	total: 3.06s	remaining: 967ms
# 76:	learn: 0.4250372	total: 3.13s	remaining: 934ms
# 77:	learn: 0.4215114	total: 3.19s	remaining: 901ms
# 78:	learn: 0.4205943	total: 3.25s	remaining: 863ms
# 79:	learn: 0.4168767	total: 3.3s	remaining: 825ms
# 80:	learn: 0.4153950	total: 3.35s	remaining: 786ms
# 81:	learn: 0.4151449	total: 3.43s	remaining: 752ms
# 82:	learn: 0.4140224	total: 3.49s	remaining: 715ms
# 83:	learn: 0.4123272	total: 3.54s	remaining: 675ms
# 84:	learn: 0.4120053	total: 3.61s	remaining: 637ms
# 85:	learn: 0.4105174	total: 3.67s	remaining: 598ms
# 86:	learn: 0.4091095	total: 3.74s	remaining: 559ms
# 87:	learn: 0.4073951	total: 3.8s	remaining: 519ms
# 88:	learn: 0.4066009	total: 3.85s	remaining: 477ms
# 89:	learn: 0.4058517	total: 3.91s	remaining: 435ms
# 90:	learn: 0.4054779	total: 3.97s	remaining: 393ms
# 91:	learn: 0.4048087	total: 4.03s	remaining: 350ms
# 92:	learn: 0.4023739	total: 4.08s	remaining: 307ms
# 93:	learn: 0.3987664	total: 4.15s	remaining: 265ms
# 94:	learn: 0.3981718	total: 4.2s	remaining: 221ms
# 95:	learn: 0.3977803	total: 4.26s	remaining: 177ms
# 96:	learn: 0.3968184	total: 4.32s	remaining: 134ms
# 97:	learn: 0.3957517	total: 4.38s	remaining: 89.5ms
# 98:	learn: 0.3953876	total: 4.46s	remaining: 45ms
# 99:	learn: 0.3947142	total: 4.52s	remaining: 0us
# CatBoost Model
# MCRMSE for reactivity: 0.4935472684357235
# MCRMSE for deg_Mg_pH10: 0.4420157776254855
# MCRMSE for deg_Mg_50C: 0.5605509169017853
# Average MCRMSE: 0.4987046543209981

# %%
# Create a MultiOutputRegressor with Random Forest
random_forest_model = MultiOutputRegressor(RandomForestRegressor(n_estimators=100, random_state=42))

# Train the model
random_forest_model.fit(X_train, y_train)

# Predict target values on the test set
y_pred = random_forest_model.predict(X_test)

# Calculate MCRMSE for each target
mcrmse_per_target = []
for i in range(len(target_features.columns)):
    mse = mean_squared_error(y_test.iloc[:, i], y_pred[:, i])
    mcrmse = np.sqrt(mse)
    mcrmse_per_target.append(mcrmse)

# Calculate average MCRMSE across all targets
average_mcrmse = np.mean(mcrmse_per_target)

# Print results
print("Random Forest Model")
for i, target in enumerate(target_features.columns):
    print(f"MCRMSE for {target}: {mcrmse_per_target[i]}")
print(f"Average MCRMSE: {average_mcrmse}\n")
# Out:
# Random Forest Model
# MCRMSE for reactivity: 0.5053379881973803
# MCRMSE for deg_Mg_pH10: 0.4091480744873961
# MCRMSE for deg_Mg_50C: 0.4756372520364208
# Average MCRMSE: 0.46337443824039903

# %%
# Create a MultiOutputRegressor with GradientBoostingRegressor
GradientBoostingRegressor_model = MultiOutputRegressor(GradientBoostingRegressor(n_estimators=100, random_state=42))

# Train the model
GradientBoostingRegressor_model.fit(X_train, y_train)

# Predict target values on the test set
y_pred = GradientBoostingRegressor_model.predict(X_test)

# Calculate MCRMSE for each target
mcrmse_per_target = []
for i in range(len(target_features.columns)):
    mse = mean_squared_error(y_test.iloc[:, i], y_pred[:, i])
    mcrmse = np.sqrt(mse)
    mcrmse_per_target.append(mcrmse)

# Calculate average MCRMSE across all targets
average_mcrmse = np.mean(mcrmse_per_target)

# Print results
print("Random Forest Model")
for i, target in enumerate(target_features.columns):
    print(f"MCRMSE for {target}: {mcrmse_per_target[i]}")
print(f"Average MCRMSE: {average_mcrmse}\n")
# Out:
# Random Forest Model
# MCRMSE for reactivity: 0.5180035197191839
# MCRMSE for deg_Mg_pH10: 0.4380689117295897
# MCRMSE for deg_Mg_50C: 0.5417245504379395
# Average MCRMSE: 0.4992656606289044

# %%
# Create a MultiOutputRegressor with XGBoostRegressor
xgboost_model = MultiOutputRegressor(XGBRegressor(
    subsample=0.8,
    colsample_bytree=0.8,
    reg_lambda=2,
    reg_alpha=1,
    n_estimators=500,
    learning_rate=0.12,
    random_state=42
))

# Train the model
xgboost_model.fit(X_train, y_train)

# Predict target values on the test set
y_pred = xgboost_model.predict(X_test)

# Calculate MCRMSE for each target
mcrmse_per_target = []
for i in range(len(target_features.columns)):
    mse = mean_squared_error(y_test.iloc[:, i], y_pred[:, i])
    mcrmse = np.sqrt(mse)
    mcrmse_per_target.append(mcrmse)

# Calculate average MCRMSE across all targets
average_mcrmse = np.mean(mcrmse_per_target)

# Print results
print("XGBoost Model")
for i, target in enumerate(target_features.columns):
    print(f"MCRMSE for {target}: {mcrmse_per_target[i]}")
print(f"Average MCRMSE: {average_mcrmse}\n")
# Out:
# XGBoost Model
# MCRMSE for reactivity: 0.3432676294430101
# MCRMSE for deg_Mg_pH10: 0.32900570328836226
# MCRMSE for deg_Mg_50C: 0.35347859427959305
# Average MCRMSE: 0.34191730900365513

# %%
# Create a MultiOutputRegressor with LinearRegression
linear_regression_model = MultiOutputRegressor(LinearRegression())

# Train the model
linear_regression_model.fit(X_train, y_train)

# Predict target values on the test set
y_pred = linear_regression_model.predict(X_test)

# Calculate MCRMSE for each target
mcrmse_per_target = []
for i in range(len(target_features.columns)):
    mse = mean_squared_error(y_test.iloc[:, i], y_pred[:, i])
    mcrmse = np.sqrt(mse)
    mcrmse_per_target.append(mcrmse)

# Calculate average MCRMSE across all targets
average_mcrmse = np.mean(mcrmse_per_target)

# Print results
print("Linear Regression Model")
for i, target in enumerate(target_features.columns):
    print(f"MCRMSE for {target}: {mcrmse_per_target[i]}")
print(f"Average MCRMSE: {average_mcrmse}\n")
# Out:
# Linear Regression Model
# MCRMSE for reactivity: 0.5742745895262231
# MCRMSE for deg_Mg_pH10: 0.5831883497835979
# MCRMSE for deg_Mg_50C: 0.6961495731885803
# Average MCRMSE: 0.6178708374994671

# %%
# Create a MultiOutputRegressor with ExtraTreesRegressor
extra_trees_model = MultiOutputRegressor(ExtraTreesRegressor(n_estimators=100, random_state=42))

# Train the model
extra_trees_model.fit(X_train, y_train)

# Predict target values on the test set
y_pred = extra_trees_model.predict(X_test)

# Calculate MCRMSE for each target
mcrmse_per_target = []
for i in range(len(target_features.columns)):
    mse = mean_squared_error(y_test.iloc[:, i], y_pred[:, i])
    mcrmse = np.sqrt(mse)
    mcrmse_per_target.append(mcrmse)

# Calculate average MCRMSE across all targets
average_mcrmse = np.mean(mcrmse_per_target)

# Print results
print("Extra Trees Model")
for i, target in enumerate(target_features.columns):
    print(f"MCRMSE for {target}: {mcrmse_per_target[i]}")
print(f"Average MCRMSE: {average_mcrmse}\n")
# Out:
# Extra Trees Model
# MCRMSE for reactivity: 0.525190703976936
# MCRMSE for deg_Mg_pH10: 0.44084416539035465
# MCRMSE for deg_Mg_50C: 0.5438405325793291
# Average MCRMSE: 0.5032918006488732

# %%
# Create a MultiOutputRegressor with AdaBoostRegressor
adaboost_model = MultiOutputRegressor(AdaBoostRegressor(n_estimators=100, random_state=42))

# Train the model
adaboost_model.fit(X_train, y_train)

# Predict target values on the test set
y_pred = adaboost_model.predict(X_test)

# Calculate MCRMSE for each target
mcrmse_per_target = []
for i in range(len(target_features.columns)):
    mse = mean_squared_error(y_test.iloc[:, i], y_pred[:, i])
    mcrmse = np.sqrt(mse)
    mcrmse_per_target.append(mcrmse)

# Calculate average MCRMSE across all targets
average_mcrmse = np.mean(mcrmse_per_target)

# Print results
print("AdaBoost Model")
for i, target in enumerate(target_features.columns):
    print(f"MCRMSE for {target}: {mcrmse_per_target[i]}")
print(f"Average MCRMSE: {average_mcrmse}\n")
# Out:
# AdaBoost Model
# MCRMSE for reactivity: 1.3042072630291706
# MCRMSE for deg_Mg_pH10: 0.9598297309951456
# MCRMSE for deg_Mg_50C: 1.0797297570598197
# Average MCRMSE: 1.1145889170280452

# %%
test_data

features_to_normalize = ['reactivity_error', 'deg_pH10', 'deg_error_50C']
test_data[features_to_normalize] = scaler.transform(test_data[features_to_normalize])

# Convert scaled values to a DataFrame for better display
test_data[features_to_normalize] = pd.DataFrame(test_data, columns=features_to_normalize)

# Display the scaled values with formatting
pd.set_option('display.float_format', '{:.10f}'.format)
test_data
# Out:
#        sequence  structure  predicted_loop_type  reactivity_error  \
# 0             2          2                    1      0.0000009169
# 1             0          2                    1      0.0000008861
# 2             3          0                    5      0.0000005043
# 3             1          0                    5      0.0000007307
# 4             3          2                    2      0.0000009367
# ...         ...        ...                  ...               ...
# 32635         0          0                    5      0.0000000493
# 32636         0          1                    5      0.0000001492
# 32637         0          2                    0      0.0000004352
# 32638         0          1                    5      0.0000001362
# 32639         2          1                    5      0.0000001375
#
#        deg_error_Mg_pH10     deg_pH10  deg_error_pH10  deg_error_Mg_50C  \
# 0           0.2613000000 0.5262201457    0.2631000000      0.1501000000
# 1           0.1798000000 0.5029263280    0.1000000000      0.1369000000
# 2           0.1056000000 0.5005621290    0.0517000000      0.0705000000
# 3           0.1896000000 0.5059733929    0.1474000000      0.1588000000
# 4           0.1810000000 0.5086138831    0.1417000000      0.1382000000
# ...                  ...          ...             ...               ...
# 32635       0.0344000000 0.5001241064    0.0303000000      0.0284000000
# 32636       0.0390000000 0.5008721142    0.0529000000      0.0361000000
# 32637       0.0672000000 0.5061867886    0.1022000000      0.0694000000
# 32638       0.0391000000 0.5018110550    0.0611000000      0.0520000000
# 32639       0.0509000000 0.5018245326    0.0719000000      0.0595000000
#
#            deg_50C  deg_error_50C  ...  b4_predicted_loop_type  \
# 0     0.6382000000   0.0000007752  ...                       0
# 1     0.7877000000   0.0000006041  ...                       2
# 2     0.0585000000   0.0000002113  ...                       2
# 3     0.7349000000   0.0000006413  ...                       6
# 4     1.0442000000   0.0000006314  ...                       6
# ...            ...            ...  ...                     ...
# 32635 0.0182000000   0.0000001147  ...                       6
# 32636 0.0237000000   0.0000001409  ...                       6
# 32637 0.4242000000   0.0000003592  ...                       5
# 32638 0.1120000000   0.0000002017  ...                       6
# 32639 0.1186000000   0.0000002427  ...                       1
#
#        a4_predicted_loop_type  b5_sequence  a5_sequence  b5_structure  \
# 0                           1            0            0             2
# 1                           5            0            1             2
# 2                           2            1            3             3
# 3                           2            1            0             3
# 4                           2            4            2             0
# ...                       ...          ...          ...           ...
# 32635                       5            2            0             0
# 32636                       5            3            2             1
# 32637                       5            3            1             1
# 32638                       5            4            1             1
# 32639                       5            2            0             1
#
#        a5_structure  b5_predicted_loop_type  a5_predicted_loop_type  \
# 0                 0                       0                       5
# 1                 0                       0                       5
# 2                 2                       2                       2
# 3                 2                       2                       2
# 4                 1                       6                       5
# ...             ...                     ...                     ...
# 32635             2                       6                       2
# 32636             1                       6                       5
# 32637             1                       6                       5
# 32638             0                       6                       5
# 32639             0                       6                       5
#
#        total_A_count  total_G_count
# 0                  4              2
# 1                  4              3
# 2                  5              1
# 3                  5              1
# 4                  5              1
# ...              ...            ...
# 32635              2              4
# 32636              2              4
# 32637              2              4
# 32638              2              2
# 32639              3              2
#
# [32640 rows x 42 columns]

# %%
# Predict target values on the test set
y_pred = xgboost_model.predict(test_data[feature_importance_df["Feature"]])

# %%
# Create a DataFrame for the predictions
prediction_df = pd.DataFrame(y_pred, columns=['reactivity', 'deg_Mg_pH10', 'deg_Mg_50C'])
prediction_df['id_seqpos'] = test_id
prediction_df = prediction_df[['id_seqpos', 'reactivity', 'deg_Mg_pH10', 'deg_Mg_50C']]

# Save the predictions to a CSV file
prediction_df.to_csv('predictions.csv', index=False)

# %%
prediction_df
# Out:
#              id_seqpos    reactivity  deg_Mg_pH10   deg_Mg_50C
# 0       id_001f94081_0  0.5212914944 0.7746857405 0.5664007664
# 1       id_001f94081_4  0.6886702180 0.5260664225 0.5813571215
# 2       id_001f94081_8  0.2849986255 0.1862083375 0.1218476892
# 3       id_001f94081_9  0.3524409235 0.8843256831 1.0188076496
# 4      id_001f94081_13  1.1513599157 1.3702285290 1.1130084991
# ...                ...           ...          ...          ...
# 32635  id_fff546103_39 -0.0115549425 0.0846866295 0.0484697334
# 32636  id_fff546103_52  0.0480578281 0.1677568108 0.1085437313
# 32637  id_fff546103_62  0.5024493933 0.5958237052 0.4661529958
# 32638  id_fff546103_65  0.0465703085 0.1841044128 0.2244262993
# 32639  id_fff546103_66  0.0125668459 0.2311172336 0.2269449085
#
# [32640 rows x 4 columns]
