# %%
# !pip install rarfile
# !pip install catboost
# Out:
# Requirement already satisfied: rarfile in /usr/local/lib/python3.10/dist-packages (4.0)
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.23.5)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.10.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)

# %%
# Importing necessary libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.multioutput import MultiOutputRegressor
from sklearn.metrics import mean_squared_error
import rarfile
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from lightgbm import LGBMRegressor
from sklearn.preprocessing import StandardScaler
from catboost import CatBoostRegressor
import xgboost as xgb
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Specify the path and filename of the RAR file
rar_path = '/content/drive/MyDrive/data/covid.rar'


# Specify the directory where you want to extract the files
extract_directory = '/content/data'
# Open the RAR file
with rarfile.RarFile(rar_path, 'r') as rar_ref:
    # Extract all the files to the specified directory
    rar_ref.extractall(extract_directory)

print('File extracted successfully.')
# Out:
# File extracted successfully.

# %%
# Load the dataset
train_data = pd.read_csv('/content/data/covid/train.csv')
train_data["id_seqpos"] = [id.split('_')[-1] for id in train_data["id_seqpos"]]

test_data = pd.read_csv('/content/data/covid/test.csv')
test_id = test_data['id_seqpos']
test_data["id_seqpos"] = [id.split('_')[-1] for id in test_data["id_seqpos"]]

# Drop target variables and id column
# Extract the multi-label target features
target_columns = ['reactivity', 'deg_Mg_pH10', 'deg_Mg_50C']
target_features = train_data[target_columns]
train_data = train_data.drop(['id'] + ["id_seqpos"], axis=1)

test_data=test_data.drop(['id']+["id_seqpos"], axis=1)

# %%
train_data
# Out:
#        sequence structure predicted_loop_type   reactivity  reactivity_error  \
# 0             A         .                   H 1.7786000000      0.1195000000
# 1             G         .                   I 0.4397000000      0.1033000000
# 2             G         (                   S 0.1120000000      0.1375000000
# 3             G         (                   S 0.0622000000      0.0471000000
# 4             U         (                   S 0.1378000000      0.1352000000
# ...         ...       ...                 ...          ...               ...
# 130555        U         )                   S 0.1244000000      0.0393000000
# 130556        A         .                   X 0.0201000000      0.0351000000
# 130557        A         .                   H 0.4597000000      0.0601000000
# 130558        G         .                   I 0.3634000000      0.1063000000
# 130559        C         .                   I 0.1458000000      0.0427000000
#
#         deg_Mg_pH10  deg_error_Mg_pH10     deg_pH10  deg_error_pH10  \
# 0      0.7346000000       0.0790000000 0.3680000000    0.0851000000
# 1      0.1630000000       0.0799000000 0.0878000000    0.0878000000
# 2      0.0000000000       0.0744000000 0.1835000000    0.1969000000
# 3      0.1179000000       0.1075000000 0.0657000000    0.0615000000
# 4      0.4069000000       0.2168000000 0.3375000000    0.2623000000
# ...             ...                ...          ...             ...
# 130555 0.2672000000       0.0728000000 0.1479000000    0.0493000000
# 130556 0.1271000000       0.0583000000 0.0580000000    0.0660000000
# 130557 0.2014000000       0.0515000000 0.2838000000    0.0793000000
# 130558 0.1928000000       0.0738000000 0.1885000000    0.1276000000
# 130559 0.4301000000       0.0687000000 0.2811000000    0.0800000000
#
#          deg_Mg_50C  ...  b4_structure  a4_structure  b4_predicted_loop_type  \
# 0      0.7228000000  ...             (             )                       S
# 1      0.1100000000  ...             (             .                       S
# 2      0.0933000000  ...             (             (                       S
# 3      0.0548000000  ...             .             (                       E
# 4      0.2378000000  ...             (             (                       S
# ...             ...  ...           ...           ...                     ...
# 130555 0.1921000000  ...             )             )                       S
# 130556 0.0245000000  ...             .             .                       H
# 130557 0.2042000000  ...             .             .                       H
# 130558 0.1627000000  ...             )             .                       S
# 130559 0.3866000000  ...             )             )                       S
#
#        a4_predicted_loop_type b5_sequence a5_sequence b5_structure  \
# 0                           S           C           A            .
# 1                           H           C           C            .
# 2                           S           A           G            (
# 3                           S           A           U            .
# 4                           S           G           G            (
# ...                       ...         ...         ...          ...
# 130555                      S           A           A            .
# 130556                      X           A           U            .
# 130557                      I           U           U            .
# 130558                      I           G           G            )
# 130559                      S           C           U            )
#
#        a5_structure b5_predicted_loop_type a5_predicted_loop_type
# 0                 )                      I                      S
# 1                 .                      B                      H
# 2                 (                      S                      S
# 3                 (                      E                      S
# 4                 .                      S                      H
# ...             ...                    ...                    ...
# 130555            .                      H                      M
# 130556            .                      H                      X
# 130557            )                      H                      S
# 130558            )                      S                      S
# 130559            )                      S                      S
#
# [130560 rows x 43 columns]

# %%
# Assuming df is your DataFrame

# Merge sequences
sequence_columns = ['sequence', 'b1_sequence', 'a1_sequence', 'b2_sequence', 'a2_sequence',
                    'b3_sequence', 'a3_sequence', 'b4_sequence', 'a4_sequence',
                    'b5_sequence', 'a5_sequence']
train_data['merged_sequence'] = train_data[sequence_columns].apply(lambda row: ''.join(row), axis=1)

# Merge structures
structure_columns = ['structure', 'b1_structure', 'a1_structure', 'b2_structure', 'a2_structure',
                     'b3_structure', 'a3_structure', 'b4_structure', 'a4_structure',
                     'b5_structure', 'a5_structure']
train_data['merged_structure'] = train_data[structure_columns].apply(lambda row: ''.join(row), axis=1)

# Merge predicted loop types
loop_type_columns = ['predicted_loop_type', 'b1_predicted_loop_type', 'a1_predicted_loop_type',
                     'b2_predicted_loop_type', 'a2_predicted_loop_type',
                     'b3_predicted_loop_type', 'a3_predicted_loop_type',
                     'b4_predicted_loop_type', 'a4_predicted_loop_type',
                     'b5_predicted_loop_type', 'a5_predicted_loop_type']
train_data['merged_predicted_loop_type'] = train_data[loop_type_columns].apply(lambda row: ''.join(row), axis=1)

# %%
train_data
# Out:
#        sequence structure predicted_loop_type   reactivity  reactivity_error  \
# 0             A         .                   H 1.7786000000      0.1195000000
# 1             G         .                   I 0.4397000000      0.1033000000
# 2             G         (                   S 0.1120000000      0.1375000000
# 3             G         (                   S 0.0622000000      0.0471000000
# 4             U         (                   S 0.1378000000      0.1352000000
# ...         ...       ...                 ...          ...               ...
# 130555        U         )                   S 0.1244000000      0.0393000000
# 130556        A         .                   X 0.0201000000      0.0351000000
# 130557        A         .                   H 0.4597000000      0.0601000000
# 130558        G         .                   I 0.3634000000      0.1063000000
# 130559        C         .                   I 0.1458000000      0.0427000000
#
#         deg_Mg_pH10  deg_error_Mg_pH10     deg_pH10  deg_error_pH10  \
# 0      0.7346000000       0.0790000000 0.3680000000    0.0851000000
# 1      0.1630000000       0.0799000000 0.0878000000    0.0878000000
# 2      0.0000000000       0.0744000000 0.1835000000    0.1969000000
# 3      0.1179000000       0.1075000000 0.0657000000    0.0615000000
# 4      0.4069000000       0.2168000000 0.3375000000    0.2623000000
# ...             ...                ...          ...             ...
# 130555 0.2672000000       0.0728000000 0.1479000000    0.0493000000
# 130556 0.1271000000       0.0583000000 0.0580000000    0.0660000000
# 130557 0.2014000000       0.0515000000 0.2838000000    0.0793000000
# 130558 0.1928000000       0.0738000000 0.1885000000    0.1276000000
# 130559 0.4301000000       0.0687000000 0.2811000000    0.0800000000
#
#          deg_Mg_50C  ...  a4_predicted_loop_type  b5_sequence  a5_sequence  \
# 0      0.7228000000  ...                       S            C            A
# 1      0.1100000000  ...                       H            C            C
# 2      0.0933000000  ...                       S            A            G
# 3      0.0548000000  ...                       S            A            U
# 4      0.2378000000  ...                       S            G            G
# ...             ...  ...                     ...          ...          ...
# 130555 0.1921000000  ...                       S            A            A
# 130556 0.0245000000  ...                       X            A            U
# 130557 0.2042000000  ...                       I            U            U
# 130558 0.1627000000  ...                       I            G            G
# 130559 0.3866000000  ...                       S            C            U
#
#        b5_structure a5_structure b5_predicted_loop_type  \
# 0                 .            )                      I
# 1                 .            .                      B
# 2                 (            (                      S
# 3                 .            (                      E
# 4                 (            .                      S
# ...             ...          ...                    ...
# 130555            .            .                      H
# 130556            .            .                      H
# 130557            .            )                      H
# 130558            )            )                      S
# 130559            )            )                      S
#
#        a5_predicted_loop_type merged_sequence merged_structure  \
# 0                           S     ACUGCUGGCCA      .(.(.()().)
# 1                           H     GGACCAGGUCC      .(.(((((...
# 2                           S     GUGUGUAUUAG      (((((((((((
# 3                           S     GCGGCGGAGAU      (((((((.(.(
# 4                           H     UGACCAGUAGG      (.((((((((.
# ...                       ...             ...              ...
# 130555                      M     UUGGAAGUAAA      )).).))))..
# 130556                      X     AUACGGAAAAU      .).).).....
# 130557                      S     AUCACAAUGUU      ..).).)...)
# 130558                      S     GCGGUGGCGGG      .))))).).))
# 130559                      S     CGUCACCGGCU      .))))))))))
#
#        merged_predicted_loop_type
# 0                     HSHSHSSSSIS
# 1                     ISISSSSSHBH
# 2                     SSSSSSSSSSS
# 3                     SSSSSSSESES
# 4                     SBSSSSSSSSH
# ...                           ...
# 130555                SSISISSSSHM
# 130556                XSXSXSXHXHX
# 130557                HHSHSHSHIHS
# 130558                ISSSSSISISS
# 130559                ISSSSSSSSSS
#
# [130560 rows x 46 columns]

# %%
# Assuming df is your DataFrame

# Merge sequences
sequence_columns = ['sequence', 'b1_sequence', 'a1_sequence', 'b2_sequence', 'a2_sequence',
                    'b3_sequence', 'a3_sequence', 'b4_sequence', 'a4_sequence',
                    'b5_sequence', 'a5_sequence']
test_data['merged_sequence'] = test_data[sequence_columns].apply(lambda row: ''.join(row), axis=1)

# Merge structures
structure_columns = ['structure', 'b1_structure', 'a1_structure', 'b2_structure', 'a2_structure',
                     'b3_structure', 'a3_structure', 'b4_structure', 'a4_structure',
                     'b5_structure', 'a5_structure']
test_data['merged_structure'] = test_data[structure_columns].apply(lambda row: ''.join(row), axis=1)

# Merge predicted loop types
loop_type_columns = ['predicted_loop_type', 'b1_predicted_loop_type', 'a1_predicted_loop_type',
                     'b2_predicted_loop_type', 'a2_predicted_loop_type',
                     'b3_predicted_loop_type', 'a3_predicted_loop_type',
                     'b4_predicted_loop_type', 'a4_predicted_loop_type',
                     'b5_predicted_loop_type', 'a5_predicted_loop_type']
test_data['merged_predicted_loop_type'] = test_data[loop_type_columns].apply(lambda row: ''.join(row), axis=1)

# Drop the original sequence, structure, and predicted_loop_type columns if needed
#train_data.drop(sequence_columns + structure_columns + loop_type_columns, axis=1, inplace=True)

# Now your DataFrame has 'merged_sequence', 'merged_structure', and 'merged_predicted_loop_type' columns

# %%
def featurize(df):

    df['total_A_count'] = df['sequence'].apply(lambda s: s.count('A'))
    df['total_G_count'] = df['sequence'].apply(lambda s: s.count('G'))
    df['total_U_count'] = df['sequence'].apply(lambda s: s.count('U'))
    df['total_C_count'] = df['sequence'].apply(lambda s: s.count('C'))

    df['total_dot_count'] = df['structure'].apply(lambda s: s.count('.'))
    df['total_ob_count'] = df['structure'].apply(lambda s: s.count('('))
    df['total_cb_count'] = df['structure'].apply(lambda s: s.count(')'))

    return df

# %%
train_data = featurize(train_data)
test_data = featurize(test_data)

# %%
train_data = train_data.drop(['merged_sequence', 'merged_structure', 'merged_predicted_loop_type'], axis=1)
test_data = test_data.drop(['merged_sequence', 'merged_structure', 'merged_predicted_loop_type'], axis=1)

# %%
train_data
# Out:
#        sequence structure predicted_loop_type   reactivity  reactivity_error  \
# 0             A         .                   H 1.7786000000      0.1195000000
# 1             G         .                   I 0.4397000000      0.1033000000
# 2             G         (                   S 0.1120000000      0.1375000000
# 3             G         (                   S 0.0622000000      0.0471000000
# 4             U         (                   S 0.1378000000      0.1352000000
# ...         ...       ...                 ...          ...               ...
# 130555        U         )                   S 0.1244000000      0.0393000000
# 130556        A         .                   X 0.0201000000      0.0351000000
# 130557        A         .                   H 0.4597000000      0.0601000000
# 130558        G         .                   I 0.3634000000      0.1063000000
# 130559        C         .                   I 0.1458000000      0.0427000000
#
#         deg_Mg_pH10  deg_error_Mg_pH10     deg_pH10  deg_error_pH10  \
# 0      0.7346000000       0.0790000000 0.3680000000    0.0851000000
# 1      0.1630000000       0.0799000000 0.0878000000    0.0878000000
# 2      0.0000000000       0.0744000000 0.1835000000    0.1969000000
# 3      0.1179000000       0.1075000000 0.0657000000    0.0615000000
# 4      0.4069000000       0.2168000000 0.3375000000    0.2623000000
# ...             ...                ...          ...             ...
# 130555 0.2672000000       0.0728000000 0.1479000000    0.0493000000
# 130556 0.1271000000       0.0583000000 0.0580000000    0.0660000000
# 130557 0.2014000000       0.0515000000 0.2838000000    0.0793000000
# 130558 0.1928000000       0.0738000000 0.1885000000    0.1276000000
# 130559 0.4301000000       0.0687000000 0.2811000000    0.0800000000
#
#          deg_Mg_50C  ...  a5_structure  b5_predicted_loop_type  \
# 0      0.7228000000  ...             )                       I
# 1      0.1100000000  ...             .                       B
# 2      0.0933000000  ...             (                       S
# 3      0.0548000000  ...             (                       E
# 4      0.2378000000  ...             .                       S
# ...             ...  ...           ...                     ...
# 130555 0.1921000000  ...             .                       H
# 130556 0.0245000000  ...             .                       H
# 130557 0.2042000000  ...             )                       H
# 130558 0.1627000000  ...             )                       S
# 130559 0.3866000000  ...             )                       S
#
#         a5_predicted_loop_type total_A_count total_G_count total_U_count  \
# 0                            S             1             0             0
# 1                            H             0             1             0
# 2                            S             0             1             0
# 3                            S             0             1             0
# 4                            H             0             0             1
# ...                        ...           ...           ...           ...
# 130555                       M             0             0             1
# 130556                       X             1             0             0
# 130557                       S             1             0             0
# 130558                       S             0             1             0
# 130559                       S             0             0             0
#
#        total_C_count total_dot_count total_ob_count total_cb_count
# 0                  0               1              0              0
# 1                  0               1              0              0
# 2                  0               0              1              0
# 3                  0               0              1              0
# 4                  0               0              1              0
# ...              ...             ...            ...            ...
# 130555             0               0              0              1
# 130556             0               1              0              0
# 130557             0               1              0              0
# 130558             0               1              0              0
# 130559             1               1              0              0
#
# [130560 rows x 50 columns]

# %%
# Identify categorical columns
from sklearn.preprocessing import LabelEncoder
categorical_columns = train_data.select_dtypes(include=['object']).columns

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Apply LabelEncoder to all categorical columns in both training and test data
for column in categorical_columns:
    # Fit LabelEncoder using training data and apply to test data
    label_encoder.fit(train_data[column])
    train_data[column] = label_encoder.transform(train_data[column])

    # Transform test data with a 'transform' call, not 'fit_transform'
    test_data[column] = test_data[column].apply(lambda x: label_encoder.transform([x])[0] if x in label_encoder.classes_ else -1)  # Use -1 for unseen labels

# %%
'''import pandas as pd
from sklearn.preprocessing import OneHotEncoder

# Assume you have the 'train_data' and 'test_data' DataFrames

# Identify categorical columns
categorical_columns = train_data.select_dtypes(include=['object']).columns

# Initialize OneHotEncoder
onehot_encoder = OneHotEncoder(sparse=False, handle_unknown='ignore')

# Fit and transform OneHotEncoder on training data
encoded_train = onehot_encoder.fit_transform(train_data[categorical_columns])
encoded_train_df = pd.DataFrame(encoded_train, columns=onehot_encoder.get_feature_names_out(categorical_columns))

# Transform test data using the trained OneHotEncoder
encoded_test = onehot_encoder.transform(test_data[categorical_columns])
encoded_test_df = pd.DataFrame(encoded_test, columns=encoded_train_df.columns)

# Replace categorical columns with encoded columns in both training and test data
train_data_encoded = pd.concat([train_data.drop(categorical_columns, axis=1), encoded_train_df], axis=1)
test_data_encoded = pd.concat([test_data.drop(categorical_columns, axis=1), encoded_test_df], axis=1)'''
# Out:
# "import pandas as pd\nfrom sklearn.preprocessing import OneHotEncoder\n\n# Assume you have the 'train_data' and 'test_data' DataFrames\n\n# Identify categorical columns\ncategorical_columns = train_data.select_dtypes(include=['object']).columns\n\n# Initialize OneHotEncoder\nonehot_encoder = OneHotEncoder(sparse=False, handle_unknown='ignore')\n\n# Fit and transform OneHotEncoder on training data\nencoded_train = onehot_encoder.fit_transform(train_data[categorical_columns])\nencoded_train_df = pd.DataFrame(encoded_train, columns=onehot_encoder.get_feature_names_out(categorical_columns))\n\n# Transform test data using the trained OneHotEncoder\nencoded_test = onehot_encoder.transform(test_data[categorical_columns])\nencoded_test_df = pd.DataFrame(encoded_test, columns=encoded_train_df.columns)\n\n# Replace categorical columns with encoded columns in both training and test data\ntrain_data_encoded = pd.concat([train_data.drop(categorical_columns, axis=1), encoded_train_df], axis=1)\ntest_data_encoded = pd.concat([test_data.drop(categorical_columns, axis=1), encoded_test_df], axis=1)"

# %%
# Split data in features and labels
target = train_data[['reactivity', 'deg_Mg_pH10', 'deg_Mg_50C']]
train_data_encoded = train_data.drop(['reactivity', 'deg_Mg_pH10', 'deg_Mg_50C'], axis=1)

# %%
# Create a Random Forest model
model = RandomForestRegressor()  # For regression



# Fit the model on the training data
model.fit(train_data_encoded, target["reactivity"])

# Get feature importance scores
feature_importances = model.feature_importances_

# Create a DataFrame to store feature names and their importance scores
feature_importance_df = pd.DataFrame({'Feature': train_data_encoded.columns, 'Importance': feature_importances})

# Sort the DataFrame by importance scores in descending order
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# %%
# Create a Random Forest model
model = RandomForestRegressor()  # For regression



# Fit the model on the training data
model.fit(train_data_encoded, target["deg_Mg_pH10"])

# Get feature importance scores
feature_importances = model.feature_importances_

# Create a DataFrame to store feature names and their importance scores
feature_importance_df1 = pd.DataFrame({'Feature': train_data_encoded.columns, 'Importance': feature_importances})

# Sort the DataFrame by importance scores in descending order
feature_importance_df1 = feature_importance_df.sort_values(by='Importance', ascending=False)

# %%
# Create a Random Forest model
model = RandomForestRegressor()  # For regression



# Fit the model on the training data
model.fit(train_data_encoded, target["deg_Mg_50C"])

# Get feature importance scores
feature_importances = model.feature_importances_

# Create a DataFrame to store feature names and their importance scores
feature_importance_df2 = pd.DataFrame({'Feature': train_data_encoded.columns, 'Importance': feature_importances})

# Sort the DataFrame by importance scores in descending order
feature_importance_df2 = feature_importance_df.sort_values(by='Importance', ascending=False)

# %%
# Normalize specified features using Min-Max scaling
scaler = MinMaxScaler()
features_to_normalize = ['reactivity_error', 'deg_pH10', 'deg_error_50C']
train_data_encoded[features_to_normalize] = scaler.fit_transform(train_data_encoded[features_to_normalize])

# Convert scaled values to a DataFrame for better display
train_data_encoded[features_to_normalize] = pd.DataFrame(train_data_encoded, columns=features_to_normalize)

# Display the scaled values with formatting
pd.set_option('display.float_format', '{:.10f}'.format)
train_data_encoded
# Out:
#         sequence  structure  predicted_loop_type  reactivity_error  \
# 0              0          2                    2      0.0000008046
# 1              2          2                    3      0.0000006938
# 2              2          0                    5      0.0000009278
# 3              2          0                    5      0.0000003093
# 4              3          0                    5      0.0000009121
# ...          ...        ...                  ...               ...
# 130555         3          1                    5      0.0000002559
# 130556         0          2                    6      0.0000002272
# 130557         0          2                    2      0.0000003982
# 130558         2          2                    3      0.0000007143
# 130559         1          2                    3      0.0000002792
#
#         deg_error_Mg_pH10     deg_pH10  deg_error_pH10  deg_error_Mg_50C  \
# 0            0.0790000000 0.5041000039    0.0851000000      0.0792000000
# 1            0.0799000000 0.5009529800    0.0878000000      0.0683000000
# 2            0.0744000000 0.5020278201    0.1969000000      0.1163000000
# 3            0.1075000000 0.5007047671    0.0615000000      0.0506000000
# 4            0.2168000000 0.5037574478    0.2623000000      0.1569000000
# ...                   ...          ...             ...               ...
# 130555       0.0728000000 0.5016279840    0.0493000000      0.0481000000
# 130556       0.0583000000 0.5006182858    0.0660000000      0.0419000000
# 130557       0.0515000000 0.5031543244    0.0793000000      0.0528000000
# 130558       0.0738000000 0.5020839768    0.1276000000      0.0773000000
# 130559       0.0687000000 0.5031239997    0.0800000000      0.0661000000
#
#             deg_50C  deg_error_50C  ...  a5_structure  b5_predicted_loop_type  \
# 0      0.5685000000   0.0000003636  ...             1                       4
# 1      0.0666000000   0.0000002947  ...             2                       1
# 2      0.0000000000   0.0000003773  ...             0                       6
# 3      0.0749000000   0.0000003127  ...             0                       2
# 4      0.6247000000   0.0000012188  ...             2                       6
# ...             ...            ...  ...           ...                     ...
# 130555 0.4711000000   0.0000003017  ...             2                       3
# 130556 0.2559000000   0.0000003592  ...             2                       3
# 130557 0.3089000000   0.0000002936  ...             1                       3
# 130558 0.1001000000   0.0000004311  ...             1                       6
# 130559 0.2609000000   0.0000002843  ...             1                       6
#
#         a5_predicted_loop_type  total_A_count  total_G_count  total_U_count  \
# 0                            5              1              0              0
# 1                            2              0              1              0
# 2                            5              0              1              0
# 3                            5              0              1              0
# 4                            2              0              0              1
# ...                        ...            ...            ...            ...
# 130555                       4              0              0              1
# 130556                       6              1              0              0
# 130557                       5              1              0              0
# 130558                       5              0              1              0
# 130559                       5              0              0              0
#
#         total_C_count  total_dot_count  total_ob_count  total_cb_count
# 0                   0                1               0               0
# 1                   0                1               0               0
# 2                   0                0               1               0
# 3                   0                0               1               0
# 4                   0                0               1               0
# ...               ...              ...             ...             ...
# 130555              0                0               0               1
# 130556              0                1               0               0
# 130557              0                1               0               0
# 130558              0                1               0               0
# 130559              1                1               0               0
#
# [130560 rows x 47 columns]

# %%
# Assuming you have loaded your data into X_train, y_train, X_test, y_test, and defined target_features
X_train, X_test, y_train, y_test = train_test_split(train_data_encoded[feature_importance_df["Feature"][0:13]], target, test_size=0.20)

# Split the data into training and testing sets
# Create a CatBoostRegressor
catboost_model = CatBoostRegressor(iterations=100)

# Train the model
catboost_model.fit(X_train, y_train["reactivity"])  # Replace "reactivity" with the desired label name

# Predict target values on the test set
y_pred = catboost_model.predict(X_test)

# Calculate RMSE
rmse = np.sqrt(mean_squared_error(y_test["reactivity"], y_pred))

# Print results
print("CatBoost Model")
print(f"RMSE for reactivity: {rmse}\n")
# Out:
# Learning rate set to 0.5
# 0:	learn: 0.6603696	total: 16.9ms	remaining: 1.67s
# 1:	learn: 0.6230197	total: 31.5ms	remaining: 1.54s
# 2:	learn: 0.6062218	total: 46.7ms	remaining: 1.51s
# 3:	learn: 0.5956023	total: 64.2ms	remaining: 1.54s
# 4:	learn: 0.5844509	total: 79.1ms	remaining: 1.5s
# 5:	learn: 0.5746262	total: 94.5ms	remaining: 1.48s
# 6:	learn: 0.5673605	total: 110ms	remaining: 1.46s
# 7:	learn: 0.5593344	total: 129ms	remaining: 1.49s
# 8:	learn: 0.5539919	total: 145ms	remaining: 1.47s
# 9:	learn: 0.5503974	total: 165ms	remaining: 1.48s
# 10:	learn: 0.5448075	total: 181ms	remaining: 1.46s
# 11:	learn: 0.5418284	total: 205ms	remaining: 1.5s
# 12:	learn: 0.5363011	total: 220ms	remaining: 1.47s
# 13:	learn: 0.5336390	total: 238ms	remaining: 1.46s
# 14:	learn: 0.5320873	total: 256ms	remaining: 1.45s
# 15:	learn: 0.5276603	total: 272ms	remaining: 1.43s
# 16:	learn: 0.5237253	total: 287ms	remaining: 1.4s
# 17:	learn: 0.5196329	total: 301ms	remaining: 1.37s
# 18:	learn: 0.5186082	total: 319ms	remaining: 1.36s
# 19:	learn: 0.5165817	total: 335ms	remaining: 1.34s
# 20:	learn: 0.5136091	total: 350ms	remaining: 1.31s
# 21:	learn: 0.5087182	total: 366ms	remaining: 1.3s
# 22:	learn: 0.5072230	total: 382ms	remaining: 1.28s
# 23:	learn: 0.5051094	total: 400ms	remaining: 1.26s
# 24:	learn: 0.5020084	total: 418ms	remaining: 1.25s
# 25:	learn: 0.5009946	total: 446ms	remaining: 1.27s
# 26:	learn: 0.5001794	total: 466ms	remaining: 1.26s
# 27:	learn: 0.4980364	total: 481ms	remaining: 1.24s
# 28:	learn: 0.4959984	total: 496ms	remaining: 1.22s
# 29:	learn: 0.4904813	total: 518ms	remaining: 1.21s
# 30:	learn: 0.4868361	total: 547ms	remaining: 1.22s
# 31:	learn: 0.4846917	total: 566ms	remaining: 1.2s
# 32:	learn: 0.4813924	total: 588ms	remaining: 1.19s
# 33:	learn: 0.4794076	total: 604ms	remaining: 1.17s
# 34:	learn: 0.4782857	total: 627ms	remaining: 1.16s
# 35:	learn: 0.4768019	total: 642ms	remaining: 1.14s
# 36:	learn: 0.4760305	total: 659ms	remaining: 1.12s
# 37:	learn: 0.4753092	total: 685ms	remaining: 1.12s
# 38:	learn: 0.4744727	total: 701ms	remaining: 1.1s
# 39:	learn: 0.4727102	total: 716ms	remaining: 1.07s
# 40:	learn: 0.4694909	total: 732ms	remaining: 1.05s
# 41:	learn: 0.4683234	total: 748ms	remaining: 1.03s
# 42:	learn: 0.4671370	total: 763ms	remaining: 1.01s
# 43:	learn: 0.4659384	total: 780ms	remaining: 992ms
# 44:	learn: 0.4652402	total: 795ms	remaining: 972ms
# 45:	learn: 0.4635023	total: 812ms	remaining: 953ms
# 46:	learn: 0.4630028	total: 836ms	remaining: 943ms
# 47:	learn: 0.4622999	total: 852ms	remaining: 923ms
# 48:	learn: 0.4615744	total: 869ms	remaining: 904ms
# 49:	learn: 0.4585496	total: 883ms	remaining: 883ms
# 50:	learn: 0.4581076	total: 902ms	remaining: 867ms
# 51:	learn: 0.4577200	total: 918ms	remaining: 848ms
# 52:	learn: 0.4565754	total: 948ms	remaining: 840ms
# 53:	learn: 0.4544739	total: 963ms	remaining: 820ms
# 54:	learn: 0.4525828	total: 978ms	remaining: 800ms
# 55:	learn: 0.4506491	total: 993ms	remaining: 780ms
# 56:	learn: 0.4502400	total: 1.01s	remaining: 762ms
# 57:	learn: 0.4484031	total: 1.03s	remaining: 744ms
# 58:	learn: 0.4481541	total: 1.05s	remaining: 728ms
# 59:	learn: 0.4469753	total: 1.06s	remaining: 709ms
# 60:	learn: 0.4456192	total: 1.08s	remaining: 689ms
# 61:	learn: 0.4449609	total: 1.09s	remaining: 670ms
# 62:	learn: 0.4438964	total: 1.11s	remaining: 651ms
# 63:	learn: 0.4425118	total: 1.12s	remaining: 632ms
# 64:	learn: 0.4404205	total: 1.14s	remaining: 613ms
# 65:	learn: 0.4399334	total: 1.15s	remaining: 595ms
# 66:	learn: 0.4396223	total: 1.18s	remaining: 581ms
# 67:	learn: 0.4393233	total: 1.2s	remaining: 563ms
# 68:	learn: 0.4388797	total: 1.21s	remaining: 545ms
# 69:	learn: 0.4370686	total: 1.23s	remaining: 526ms
# 70:	learn: 0.4350829	total: 1.25s	remaining: 510ms
# 71:	learn: 0.4347358	total: 1.27s	remaining: 493ms
# 72:	learn: 0.4338784	total: 1.28s	remaining: 475ms
# 73:	learn: 0.4331055	total: 1.3s	remaining: 457ms
# 74:	learn: 0.4327485	total: 1.31s	remaining: 438ms
# 75:	learn: 0.4324504	total: 1.33s	remaining: 422ms
# 76:	learn: 0.4318453	total: 1.35s	remaining: 404ms
# 77:	learn: 0.4314863	total: 1.37s	remaining: 386ms
# 78:	learn: 0.4312866	total: 1.39s	remaining: 368ms
# 79:	learn: 0.4309506	total: 1.4s	remaining: 350ms
# 80:	learn: 0.4291862	total: 1.42s	remaining: 332ms
# 81:	learn: 0.4271145	total: 1.44s	remaining: 316ms
# 82:	learn: 0.4253611	total: 1.47s	remaining: 300ms
# 83:	learn: 0.4248710	total: 1.48s	remaining: 283ms
# 84:	learn: 0.4245420	total: 1.5s	remaining: 265ms
# 85:	learn: 0.4243364	total: 1.52s	remaining: 248ms
# 86:	learn: 0.4233953	total: 1.54s	remaining: 230ms
# 87:	learn: 0.4230326	total: 1.55s	remaining: 212ms
# 88:	learn: 0.4212684	total: 1.57s	remaining: 194ms
# 89:	learn: 0.4205779	total: 1.58s	remaining: 176ms
# 90:	learn: 0.4188932	total: 1.6s	remaining: 158ms
# 91:	learn: 0.4187252	total: 1.62s	remaining: 141ms
# 92:	learn: 0.4185450	total: 1.64s	remaining: 123ms
# 93:	learn: 0.4174448	total: 1.66s	remaining: 106ms
# 94:	learn: 0.4164591	total: 1.68s	remaining: 88.6ms
# 95:	learn: 0.4153091	total: 1.7s	remaining: 70.8ms
# 96:	learn: 0.4141916	total: 1.71s	remaining: 53ms
# 97:	learn: 0.4139031	total: 1.73s	remaining: 35.3ms
# 98:	learn: 0.4126169	total: 1.75s	remaining: 17.6ms
# 99:	learn: 0.4122245	total: 1.76s	remaining: 0us
# CatBoost Model
# RMSE for reactivity: 0.4433622727458411

# %%
# Assuming you have loaded your data into X_train, y_train, X_test, y_test, and defined target_features
X_train1, X_test1, y_train1, y_test1 = train_test_split(train_data_encoded[feature_importance_df1["Feature"][:18]], target, test_size=0.20)

# Split the data into training and testing sets
# Create a CatBoostRegressor
catboost_model = CatBoostRegressor(iterations=100)

# Train the model
catboost_model.fit(X_train1, y_train1["deg_Mg_pH10"])  # Replace "reactivity" with the desired label name

# Predict target values on the test set
y_pred = catboost_model.predict(X_test1)

# Calculate RMSE
rmse = np.sqrt(mean_squared_error(y_test1["deg_Mg_pH10"], y_pred))

# Print results
print("CatBoost Model")
print(f"RMSE for reactivity: {rmse}\n")
# Out:
# Learning rate set to 0.5
# 0:	learn: 0.6144460	total: 16.6ms	remaining: 1.64s
# 1:	learn: 0.5683103	total: 32.1ms	remaining: 1.57s
# 2:	learn: 0.5449084	total: 47.7ms	remaining: 1.54s
# 3:	learn: 0.5335435	total: 63.8ms	remaining: 1.53s
# 4:	learn: 0.5246309	total: 79.6ms	remaining: 1.51s
# 5:	learn: 0.5177807	total: 108ms	remaining: 1.7s
# 6:	learn: 0.5118515	total: 129ms	remaining: 1.71s
# 7:	learn: 0.5024431	total: 145ms	remaining: 1.67s
# 8:	learn: 0.4971100	total: 163ms	remaining: 1.64s
# 9:	learn: 0.4935671	total: 180ms	remaining: 1.62s
# 10:	learn: 0.4883439	total: 201ms	remaining: 1.62s
# 11:	learn: 0.4829388	total: 218ms	remaining: 1.59s
# 12:	learn: 0.4782977	total: 233ms	remaining: 1.56s
# 13:	learn: 0.4750363	total: 251ms	remaining: 1.54s
# 14:	learn: 0.4708517	total: 270ms	remaining: 1.53s
# 15:	learn: 0.4686279	total: 288ms	remaining: 1.51s
# 16:	learn: 0.4652697	total: 305ms	remaining: 1.49s
# 17:	learn: 0.4622394	total: 321ms	remaining: 1.46s
# 18:	learn: 0.4594906	total: 338ms	remaining: 1.44s
# 19:	learn: 0.4563626	total: 354ms	remaining: 1.41s
# 20:	learn: 0.4536589	total: 370ms	remaining: 1.39s
# 21:	learn: 0.4521641	total: 392ms	remaining: 1.39s
# 22:	learn: 0.4505537	total: 421ms	remaining: 1.41s
# 23:	learn: 0.4487420	total: 437ms	remaining: 1.38s
# 24:	learn: 0.4472408	total: 455ms	remaining: 1.36s
# 25:	learn: 0.4459601	total: 474ms	remaining: 1.35s
# 26:	learn: 0.4421447	total: 490ms	remaining: 1.32s
# 27:	learn: 0.4395248	total: 507ms	remaining: 1.3s
# 28:	learn: 0.4376864	total: 531ms	remaining: 1.3s
# 29:	learn: 0.4365164	total: 549ms	remaining: 1.28s
# 30:	learn: 0.4354191	total: 568ms	remaining: 1.26s
# 31:	learn: 0.4344091	total: 584ms	remaining: 1.24s
# 32:	learn: 0.4333969	total: 604ms	remaining: 1.23s
# 33:	learn: 0.4305837	total: 619ms	remaining: 1.2s
# 34:	learn: 0.4293648	total: 636ms	remaining: 1.18s
# 35:	learn: 0.4286081	total: 653ms	remaining: 1.16s
# 36:	learn: 0.4278352	total: 672ms	remaining: 1.14s
# 37:	learn: 0.4258255	total: 687ms	remaining: 1.12s
# 38:	learn: 0.4252324	total: 705ms	remaining: 1.1s
# 39:	learn: 0.4221539	total: 729ms	remaining: 1.09s
# 40:	learn: 0.4210150	total: 746ms	remaining: 1.07s
# 41:	learn: 0.4204734	total: 769ms	remaining: 1.06s
# 42:	learn: 0.4195112	total: 786ms	remaining: 1.04s
# 43:	learn: 0.4188297	total: 806ms	remaining: 1.02s
# 44:	learn: 0.4172697	total: 827ms	remaining: 1.01s
# 45:	learn: 0.4159672	total: 850ms	remaining: 998ms
# 46:	learn: 0.4147237	total: 878ms	remaining: 991ms
# 47:	learn: 0.4140758	total: 898ms	remaining: 973ms
# 48:	learn: 0.4135958	total: 937ms	remaining: 976ms
# 49:	learn: 0.4132496	total: 983ms	remaining: 983ms
# 50:	learn: 0.4109927	total: 1.03s	remaining: 991ms
# 51:	learn: 0.4100528	total: 1.07s	remaining: 992ms
# 52:	learn: 0.4094937	total: 1.14s	remaining: 1.01s
# 53:	learn: 0.4083801	total: 1.18s	remaining: 1s
# 54:	learn: 0.4062032	total: 1.21s	remaining: 993ms
# 55:	learn: 0.4047033	total: 1.26s	remaining: 988ms
# 56:	learn: 0.4037961	total: 1.3s	remaining: 983ms
# 57:	learn: 0.4027172	total: 1.33s	remaining: 960ms
# 58:	learn: 0.4011848	total: 1.36s	remaining: 945ms
# 59:	learn: 0.4001912	total: 1.4s	remaining: 935ms
# 60:	learn: 0.3989841	total: 1.44s	remaining: 921ms
# 61:	learn: 0.3984066	total: 1.48s	remaining: 906ms
# 62:	learn: 0.3975052	total: 1.5s	remaining: 882ms
# 63:	learn: 0.3961865	total: 1.52s	remaining: 857ms
# 64:	learn: 0.3954926	total: 1.54s	remaining: 832ms
# 65:	learn: 0.3947894	total: 1.58s	remaining: 816ms
# 66:	learn: 0.3941397	total: 1.63s	remaining: 801ms
# 67:	learn: 0.3935676	total: 1.66s	remaining: 783ms
# 68:	learn: 0.3930033	total: 1.71s	remaining: 767ms
# 69:	learn: 0.3918509	total: 1.74s	remaining: 748ms
# 70:	learn: 0.3913630	total: 1.79s	remaining: 730ms
# 71:	learn: 0.3911830	total: 1.83s	remaining: 714ms
# 72:	learn: 0.3905000	total: 1.89s	remaining: 699ms
# 73:	learn: 0.3896541	total: 1.93s	remaining: 680ms
# 74:	learn: 0.3883702	total: 1.96s	remaining: 653ms
# 75:	learn: 0.3879219	total: 1.99s	remaining: 627ms
# 76:	learn: 0.3863284	total: 2.01s	remaining: 600ms
# 77:	learn: 0.3859324	total: 2.04s	remaining: 577ms
# 78:	learn: 0.3855164	total: 2.09s	remaining: 555ms
# 79:	learn: 0.3841698	total: 2.14s	remaining: 535ms
# 80:	learn: 0.3837655	total: 2.19s	remaining: 514ms
# 81:	learn: 0.3835214	total: 2.24s	remaining: 492ms
# 82:	learn: 0.3828631	total: 2.27s	remaining: 466ms
# 83:	learn: 0.3822453	total: 2.31s	remaining: 440ms
# 84:	learn: 0.3820490	total: 2.36s	remaining: 416ms
# 85:	learn: 0.3815896	total: 2.4s	remaining: 392ms
# 86:	learn: 0.3810238	total: 2.44s	remaining: 365ms
# 87:	learn: 0.3804473	total: 2.48s	remaining: 339ms
# 88:	learn: 0.3800099	total: 2.53s	remaining: 312ms
# 89:	learn: 0.3797178	total: 2.58s	remaining: 286ms
# 90:	learn: 0.3791573	total: 2.62s	remaining: 259ms
# 91:	learn: 0.3789484	total: 2.67s	remaining: 232ms
# 92:	learn: 0.3784670	total: 2.72s	remaining: 205ms
# 93:	learn: 0.3778180	total: 2.76s	remaining: 176ms
# 94:	learn: 0.3775585	total: 2.81s	remaining: 148ms
# 95:	learn: 0.3764414	total: 2.85s	remaining: 119ms
# 96:	learn: 0.3759154	total: 2.89s	remaining: 89.5ms
# 97:	learn: 0.3743814	total: 2.94s	remaining: 59.9ms
# 98:	learn: 0.3741438	total: 2.99s	remaining: 30.2ms
# 99:	learn: 0.3734571	total: 3.05s	remaining: 0us
# CatBoost Model
# RMSE for reactivity: 0.4433469527595329

# %%
# Assuming you have loaded your data into X_train, y_train, X_test, y_test, and defined target_features
X_train2, X_test2, y_train2, y_test2 = train_test_split(train_data_encoded[feature_importance_df2["Feature"]], target, test_size=0.20)

# Split the data into training and testing sets
# Create a CatBoostRegressor
catboost_model = CatBoostRegressor(iterations=100)

# Train the model
catboost_model.fit(X_train2, y_train2["deg_Mg_50C"])  # Replace "reactivity" with the desired label name

# Predict target values on the test set
y_pred = catboost_model.predict(X_test2)

# Calculate RMSE
rmse = np.sqrt(mean_squared_error(y_test2["deg_Mg_50C"], y_pred))

# Print results
print("CatBoost Model")
print(f"RMSE for reactivity: {rmse}\n")
# Out:
# Learning rate set to 0.5
# 0:	learn: 0.7098125	total: 58.1ms	remaining: 5.75s
# 1:	learn: 0.6569900	total: 110ms	remaining: 5.38s
# 2:	learn: 0.6347711	total: 162ms	remaining: 5.25s
# 3:	learn: 0.6226481	total: 232ms	remaining: 5.56s
# 4:	learn: 0.6078190	total: 276ms	remaining: 5.25s
# 5:	learn: 0.6018697	total: 342ms	remaining: 5.35s
# 6:	learn: 0.5950135	total: 404ms	remaining: 5.37s
# 7:	learn: 0.5881990	total: 452ms	remaining: 5.19s
# 8:	learn: 0.5824854	total: 494ms	remaining: 5s
# 9:	learn: 0.5780516	total: 558ms	remaining: 5.02s
# 10:	learn: 0.5750826	total: 609ms	remaining: 4.92s
# 11:	learn: 0.5702124	total: 667ms	remaining: 4.89s
# 12:	learn: 0.5656611	total: 718ms	remaining: 4.8s
# 13:	learn: 0.5631180	total: 781ms	remaining: 4.8s
# 14:	learn: 0.5578150	total: 818ms	remaining: 4.64s
# 15:	learn: 0.5552474	total: 864ms	remaining: 4.54s
# 16:	learn: 0.5538678	total: 901ms	remaining: 4.4s
# 17:	learn: 0.5505330	total: 924ms	remaining: 4.21s
# 18:	learn: 0.5471163	total: 947ms	remaining: 4.04s
# 19:	learn: 0.5445220	total: 972ms	remaining: 3.89s
# 20:	learn: 0.5394879	total: 995ms	remaining: 3.74s
# 21:	learn: 0.5385250	total: 1.02s	remaining: 3.62s
# 22:	learn: 0.5348664	total: 1.05s	remaining: 3.51s
# 23:	learn: 0.5336613	total: 1.08s	remaining: 3.42s
# 24:	learn: 0.5304270	total: 1.11s	remaining: 3.33s
# 25:	learn: 0.5290509	total: 1.14s	remaining: 3.24s
# 26:	learn: 0.5256786	total: 1.16s	remaining: 3.13s
# 27:	learn: 0.5241473	total: 1.18s	remaining: 3.03s
# 28:	learn: 0.5216239	total: 1.21s	remaining: 2.96s
# 29:	learn: 0.5164630	total: 1.24s	remaining: 2.9s
# 30:	learn: 0.5143258	total: 1.26s	remaining: 2.81s
# 31:	learn: 0.5131068	total: 1.28s	remaining: 2.73s
# 32:	learn: 0.5099045	total: 1.32s	remaining: 2.68s
# 33:	learn: 0.5064684	total: 1.34s	remaining: 2.6s
# 34:	learn: 0.5048677	total: 1.39s	remaining: 2.57s
# 35:	learn: 0.5018619	total: 1.41s	remaining: 2.51s
# 36:	learn: 0.5009955	total: 1.44s	remaining: 2.45s
# 37:	learn: 0.4913289	total: 1.46s	remaining: 2.39s
# 38:	learn: 0.4903334	total: 1.49s	remaining: 2.33s
# 39:	learn: 0.4878662	total: 1.51s	remaining: 2.26s
# 40:	learn: 0.4867703	total: 1.53s	remaining: 2.21s
# 41:	learn: 0.4860287	total: 1.56s	remaining: 2.15s
# 42:	learn: 0.4851446	total: 1.58s	remaining: 2.1s
# 43:	learn: 0.4784815	total: 1.6s	remaining: 2.04s
# 44:	learn: 0.4761617	total: 1.63s	remaining: 1.99s
# 45:	learn: 0.4755111	total: 1.66s	remaining: 1.95s
# 46:	learn: 0.4733951	total: 1.68s	remaining: 1.9s
# 47:	learn: 0.4718767	total: 1.71s	remaining: 1.85s
# 48:	learn: 0.4670223	total: 1.74s	remaining: 1.81s
# 49:	learn: 0.4664891	total: 1.78s	remaining: 1.78s
# 50:	learn: 0.4631353	total: 1.8s	remaining: 1.73s
# 51:	learn: 0.4622712	total: 1.82s	remaining: 1.69s
# 52:	learn: 0.4605832	total: 1.85s	remaining: 1.64s
# 53:	learn: 0.4585461	total: 1.87s	remaining: 1.59s
# 54:	learn: 0.4582207	total: 1.89s	remaining: 1.55s
# 55:	learn: 0.4571327	total: 1.92s	remaining: 1.51s
# 56:	learn: 0.4567323	total: 1.96s	remaining: 1.48s
# 57:	learn: 0.4559887	total: 1.98s	remaining: 1.44s
# 58:	learn: 0.4555353	total: 2.01s	remaining: 1.4s
# 59:	learn: 0.4522433	total: 2.04s	remaining: 1.36s
# 60:	learn: 0.4511649	total: 2.06s	remaining: 1.31s
# 61:	learn: 0.4507696	total: 2.09s	remaining: 1.28s
# 62:	learn: 0.4499892	total: 2.11s	remaining: 1.24s
# 63:	learn: 0.4494245	total: 2.13s	remaining: 1.2s
# 64:	learn: 0.4483311	total: 2.15s	remaining: 1.16s
# 65:	learn: 0.4472461	total: 2.18s	remaining: 1.12s
# 66:	learn: 0.4451347	total: 2.23s	remaining: 1.1s
# 67:	learn: 0.4446544	total: 2.25s	remaining: 1.06s
# 68:	learn: 0.4439504	total: 2.28s	remaining: 1.02s
# 69:	learn: 0.4423215	total: 2.3s	remaining: 986ms
# 70:	learn: 0.4405292	total: 2.32s	remaining: 949ms
# 71:	learn: 0.4385560	total: 2.35s	remaining: 915ms
# 72:	learn: 0.4376135	total: 2.38s	remaining: 879ms
# 73:	learn: 0.4357186	total: 2.4s	remaining: 844ms
# 74:	learn: 0.4346441	total: 2.43s	remaining: 809ms
# 75:	learn: 0.4342642	total: 2.45s	remaining: 774ms
# 76:	learn: 0.4317572	total: 2.47s	remaining: 739ms
# 77:	learn: 0.4312475	total: 2.51s	remaining: 708ms
# 78:	learn: 0.4291006	total: 2.53s	remaining: 673ms
# 79:	learn: 0.4271591	total: 2.56s	remaining: 640ms
# 80:	learn: 0.4269837	total: 2.59s	remaining: 607ms
# 81:	learn: 0.4265408	total: 2.62s	remaining: 575ms
# 82:	learn: 0.4253738	total: 2.65s	remaining: 542ms
# 83:	learn: 0.4251636	total: 2.68s	remaining: 510ms
# 84:	learn: 0.4243198	total: 2.71s	remaining: 478ms
# 85:	learn: 0.4237062	total: 2.74s	remaining: 445ms
# 86:	learn: 0.4227448	total: 2.76s	remaining: 412ms
# 87:	learn: 0.4209791	total: 2.79s	remaining: 380ms
# 88:	learn: 0.4201852	total: 2.81s	remaining: 347ms
# 89:	learn: 0.4186994	total: 2.84s	remaining: 315ms
# 90:	learn: 0.4176087	total: 2.86s	remaining: 283ms
# 91:	learn: 0.4167487	total: 2.88s	remaining: 250ms
# 92:	learn: 0.4154455	total: 2.9s	remaining: 218ms
# 93:	learn: 0.4152063	total: 2.93s	remaining: 187ms
# 94:	learn: 0.4146706	total: 2.95s	remaining: 156ms
# 95:	learn: 0.4133915	total: 2.98s	remaining: 124ms
# 96:	learn: 0.4130066	total: 3s	remaining: 92.9ms
# 97:	learn: 0.4112503	total: 3.03s	remaining: 61.8ms
# 98:	learn: 0.4107436	total: 3.06s	remaining: 30.9ms
# 99:	learn: 0.4093654	total: 3.08s	remaining: 0us
# CatBoost Model
# RMSE for reactivity: 0.5069426967378243

# %%
# Create an XGBoost model
xgb_model = xgb.XGBRegressor(
 subsample=0.8,
    colsample_bytree=0.8,
    reg_lambda=2,
    reg_alpha=1,
    n_estimators = 800,
    learning_rate =0.18,
    max_depth = 5
)

# Train the model
xgb_model.fit(X_train, y_train["reactivity"])  # Replace "reactivity" with the desired label name
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.18, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=800, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
# Predict target values on the test set
y_pred = xgb_model.predict(X_test)

# Calculate RMSE
rmse = np.sqrt(mean_squared_error(y_test["reactivity"], y_pred))

# Print results
print("XGBoost Model")
print(f"RMSE for reactivity: {rmse}\n")
# Out:
# XGBoost Model
# RMSE for reactivity: 0.3504704295834129

# %%
# Assuming you have loaded your data into X_train, y_train, X_test, y_test, and defined target_features

# Create an XGBoost model
xgb_model1 = xgb.XGBRegressor(
   subsample=0.8,
    colsample_bytree=0.8,
    reg_lambda=2,
    reg_alpha=1,

    n_estimators = 800,
    learning_rate = 0.12,

)

# Train the model
xgb_model1.fit(X_train1, y_train1["deg_Mg_pH10"])  # Replace "reactivity" with the desired label name

# Predict target values on the test set
y_pred = xgb_model1.predict(X_test)

# Calculate RMSE
rmse = np.sqrt(mean_squared_error(y_test["deg_Mg_pH10"], y_pred))

# Print results
print("XGBoost Model")
print(f"RMSE for reactivity: {rmse}\n")
# Out:
# XGBoost Model
# RMSE for reactivity: 0.26407720207456803

# %%
# Create an XGBoost model
xgb_model2 = XGBRegressor(
    subsample=0.8,
    colsample_bytree=0.8,
    reg_lambda=2,
    reg_alpha=1,
    n_estimators=800,
    learning_rate=0.12,
    max_depth=5
)

# Train the XGBoost model
xgb_model2.fit(X_train2, y_train2["deg_Mg_50C"])

# Predict target values using the XGBoost model
y_pred_xgb = xgb_model2.predict(X_test2)

# Calculate RMSE for XGBoost model
rmse_xgb = np.sqrt(mean_squared_error(y_test2["deg_Mg_50C"], y_pred_xgb))



print("XGBoost Model")
print(f"RMSE for deg_Mg_50C (XGBoost): {rmse_xgb}\n")
# Out:
# XGBoost Model
# RMSE for deg_Mg_50C (XGBoost): 0.34474230633822217

# %%
test_data

features_to_normalize = ['reactivity_error', 'deg_pH10', 'deg_error_50C']
test_data[features_to_normalize] = scaler.transform(test_data[features_to_normalize])

# Convert scaled values to a DataFrame for better display
test_data[features_to_normalize] = pd.DataFrame(test_data, columns=features_to_normalize)

# Display the scaled values with formatting
pd.set_option('display.float_format', '{:.10f}'.format)
test_data
# Out:
#        sequence  structure  predicted_loop_type  reactivity_error  \
# 0             2          2                    1      0.0000009169
# 1             0          2                    1      0.0000008861
# 2             3          0                    5      0.0000005043
# 3             1          0                    5      0.0000007307
# 4             3          2                    2      0.0000009367
# ...         ...        ...                  ...               ...
# 32635         0          0                    5      0.0000000493
# 32636         0          1                    5      0.0000001492
# 32637         0          2                    0      0.0000004352
# 32638         0          1                    5      0.0000001362
# 32639         2          1                    5      0.0000001375
#
#        deg_error_Mg_pH10     deg_pH10  deg_error_pH10  deg_error_Mg_50C  \
# 0           0.2613000000 0.5262201457    0.2631000000      0.1501000000
# 1           0.1798000000 0.5029263280    0.1000000000      0.1369000000
# 2           0.1056000000 0.5005621290    0.0517000000      0.0705000000
# 3           0.1896000000 0.5059733929    0.1474000000      0.1588000000
# 4           0.1810000000 0.5086138831    0.1417000000      0.1382000000
# ...                  ...          ...             ...               ...
# 32635       0.0344000000 0.5001241064    0.0303000000      0.0284000000
# 32636       0.0390000000 0.5008721142    0.0529000000      0.0361000000
# 32637       0.0672000000 0.5061867886    0.1022000000      0.0694000000
# 32638       0.0391000000 0.5018110550    0.0611000000      0.0520000000
# 32639       0.0509000000 0.5018245326    0.0719000000      0.0595000000
#
#            deg_50C  deg_error_50C  ...  a5_structure  b5_predicted_loop_type  \
# 0     0.6382000000   0.0000007752  ...             0                       0
# 1     0.7877000000   0.0000006041  ...             0                       0
# 2     0.0585000000   0.0000002113  ...             2                       2
# 3     0.7349000000   0.0000006413  ...             2                       2
# 4     1.0442000000   0.0000006314  ...             1                       6
# ...            ...            ...  ...           ...                     ...
# 32635 0.0182000000   0.0000001147  ...             2                       6
# 32636 0.0237000000   0.0000001409  ...             1                       6
# 32637 0.4242000000   0.0000003592  ...             1                       6
# 32638 0.1120000000   0.0000002017  ...             0                       6
# 32639 0.1186000000   0.0000002427  ...             0                       6
#
#        a5_predicted_loop_type  total_A_count  total_G_count  total_U_count  \
# 0                           5              0              1              0
# 1                           5              1              0              0
# 2                           2              0              0              1
# 3                           2              0              0              0
# 4                           5              0              0              1
# ...                       ...            ...            ...            ...
# 32635                       2              1              0              0
# 32636                       5              1              0              0
# 32637                       5              1              0              0
# 32638                       5              1              0              0
# 32639                       5              0              1              0
#
#        total_C_count  total_dot_count  total_ob_count  total_cb_count
# 0                  0                1               0               0
# 1                  0                1               0               0
# 2                  0                0               1               0
# 3                  1                0               1               0
# 4                  0                1               0               0
# ...              ...              ...             ...             ...
# 32635              0                0               1               0
# 32636              0                0               0               1
# 32637              0                1               0               0
# 32638              0                0               0               1
# 32639              0                0               0               1
#
# [32640 rows x 47 columns]

# %%
y_pred2 = xgb_model.predict(test_data[feature_importance_df["Feature"][0:13]])
y_pred3 = xgb_model1.predict(test_data[feature_importance_df1["Feature"][0:18]])

# %%
# Now remove the column from prediction_df3
#test_data2.drop(columns='deg_Mg_pH10', inplace=True)

# %%
y_pred = xgb_model2.predict(test_data[feature_importance_df2["Feature"]])

# %%
# Create a DataFrame for the predictions
prediction_dict = {
    'id_seqpos': test_id,
    'reactivity': y_pred2,
    'deg_Mg_pH10': y_pred3,
    'deg_Mg_50C': y_pred
}

prediction_df = pd.DataFrame(prediction_dict)

# Save the predictions to a CSV file
prediction_df.to_csv('predictions.csv', index=False)

# %%
prediction_df
# Out:
#              id_seqpos    reactivity  deg_Mg_pH10   deg_Mg_50C
# 0       id_001f94081_0  0.4398843050 0.8117605448 0.5366960168
# 1       id_001f94081_4  0.8943917155 0.4686833024 0.6369154453
# 2       id_001f94081_8  0.3298865259 0.1719706655 0.1265527010
# 3       id_001f94081_9  0.5688855052 0.9699054360 0.9917514324
# 4      id_001f94081_13  1.0647768974 1.2408246994 1.0858554840
# ...                ...           ...          ...          ...
# 32635  id_fff546103_39 -0.0053966413 0.0838072449 0.0666786954
# 32636  id_fff546103_52  0.0184414722 0.1455953866 0.1061036661
# 32637  id_fff546103_62  0.4225301147 0.5312647223 0.4693120122
# 32638  id_fff546103_65  0.0182480700 0.2032098472 0.2401004881
# 32639  id_fff546103_66  0.0023502789 0.2098004073 0.2353450954
#
# [32640 rows x 4 columns]
